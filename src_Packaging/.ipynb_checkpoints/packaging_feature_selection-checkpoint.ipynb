# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulmnair1997/LabelMaster_Sales_Forecasting/blob/main/EDA_books.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sys
import numpy as np
import warnings
from feature_selector import FeatureSelector
warnings.filterwarnings('ignore')

# %%
#df = pd.read_csv('C:/Users/11602/OneDrive/Practicum/LabelMaster_Sales_Forecasting/data/Packaging_ext.csv', index_col=0)
df = pd.read_csv('C:/Users/Sword Guo/OneDrive/Practicum/LabelMaster_Sales_Forecasting/data/Packaging_ext.csv', index_col=0)

df
# Out:
#     Year_Month  Sum of Sales  \
# 0      2008-01     381696.51
# 1      2008-02     430305.85
# 2      2008-03     451627.81
# 3      2008-04     467417.48
# 4      2008-05     462676.37
# ..         ...           ...
# 152    2020-09     980476.36
# 153    2020-10     922901.36
# 154    2020-11     293486.93
# 155    2020-12     557010.14
# 156    2021-01      78188.86
#
#      FTR Truck Loadings (000s, SA)_freight_m_trucking  \
# 0                                        57633.608984
# 1                                        57175.659828
# 2                                        56814.700553
# 3                                        56916.813852
# 4                                        56194.246889
# ..                                                ...
# 152                                      62170.174317
# 153                                      62870.759335
# 154                                      63237.027387
# 155                                               NaN
# 156                                               NaN
#
#      FTR Truck Loadings Index (2000=100)_freight_m_trucking  \
# 0                                           102.678075
# 1                                           101.862208
# 2                                           101.219136
# 3                                           101.401057
# 4                                           100.113756
# ..                                                 ...
# 152                                         110.760265
# 153                                         112.008404
# 154                                         112.660934
# 155                                                NaN
# 156                                                NaN
#
#      FTR Active Truck Utilization (%, SA)_freight_m_trucking  \
# 0                                            88.294650
# 1                                            87.998407
# 2                                            87.790155
# 3                                            89.639867
# 4                                            89.134818
# ..                                                 ...
# 152                                          90.587889
# 153                                          94.367218
# 154                                          95.404858
# 155                                                NaN
# 156                                                NaN
#
#      Dry Van Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                         18021.824048
# 1                                         17917.808139
# 2                                         17835.922848
# 3                                         17713.172439
# 4                                         17561.485366
# ..                                                 ...
# 152                                       20315.722086
# 153                                       20404.155544
# 154                                       20455.350315
# 155                                                NaN
# 156                                                NaN
#
#      Reefer Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                          3940.638792
# 1                                          3927.115595
# 2                                          3922.853376
# 3                                          3978.633479
# 4                                          3990.692209
# ..                                                 ...
# 152                                        4381.188114
# 153                                        4436.920215
# 154                                        4457.161049
# 155                                                NaN
# 156                                                NaN
#
#      Flatbed Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                          6425.307387
# 1                                          6323.986294
# 2                                          6352.228095
# 3                                          6304.602493
# 4                                          6213.659026
# ..                                                 ...
# 152                                        7049.924576
# 153                                        7199.060314
# 154                                        7260.723423
# 155                                                NaN
# 156                                                NaN
#
#      Tank Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                          6915.782704
# 1                                          6836.939472
# 2                                          6758.129439
# 3                                          6858.428982
# 4                                          6804.610846
# ..                                                 ...
# 152                                        6556.745680
# 153                                        6523.796564
# 154                                        6528.943165
# 155                                                NaN
# 156                                                NaN
#
#      Bulk Trailer/Straight Truck Loadings (000s, SA)_freight_m_trucking  ...  \
# 0                                         22330.056054                   ...
# 1                                         22169.810328                   ...
# 2                                         21945.566795                   ...
# 3                                         22061.976458                   ...
# 4                                         21623.799441                   ...
# ..                                                 ...                   ...
# 152                                       23866.593861                   ...
# 153                                       24306.826698                   ...
# 154                                       24534.849434                   ...
# 155                                                NaN                   ...
# 156                                                NaN                   ...
#
#      East Coast Port Activity, Total TEUs_Exports_y.1  \
# 0                                       446657.730000
# 1                                       472359.530000
# 2                                       493039.820000
# 3                                       484342.050000
# 4                                       499498.010000
# ..                                                ...
# 152                                     492325.048120
# 153                                     546879.252290
# 154                                     536326.504108
# 155                                               NaN
# 156                                               NaN
#
#      East Coast Port Activity, Total TEUs_SA Imports_y.1  \
# 0                                         5.723749e+05
# 1                                         5.943458e+05
# 2                                         5.561473e+05
# 3                                         5.689482e+05
# 4                                         5.529787e+05
# ..                                                 ...
# 152                                       9.480849e+05
# 153                                       9.980584e+05
# 154                                       1.030347e+06
# 155                                                NaN
# 156                                                NaN
#
#      Gulf Coast Port Activity, Total TEUs_Imports_y.1  \
# 0                                        58486.560000
# 1                                        62079.760000
# 2                                        63169.270000
# 3                                        63221.100000
# 4                                        61657.850000
# ..                                                ...
# 152                                     156153.318284
# 153                                     173631.303295
# 154                                     157277.954482
# 155                                               NaN
# 156                                               NaN
#
#      Gulf Coast Port Activity, Total TEUs_Exports_y.1  \
# 0                                        90322.590000
# 1                                       100410.660000
# 2                                        93384.280000
# 3                                       101642.940000
# 4                                       105424.640000
# ..                                                ...
# 152                                     117576.128306
# 153                                     123604.184721
# 154                                     130627.239881
# 155                                               NaN
# 156                                               NaN
#
#      Gulf Coast Port Activity, Total TEUs_SA Imports_y.1  \
# 0                                         61444.608268
# 1                                         69356.289323
# 2                                         61534.312686
# 3                                         63038.826932
# 4                                         59864.174184
# ..                                                 ...
# 152                                      154165.434806
# 153                                      162787.138608
# 154                                      166005.768833
# 155                                                NaN
# 156                                                NaN
#
#      Western Canadian Port Activity, Total TEUs_Imports_y.1  \
# 0                                          97597.00000
# 1                                         105664.00000
# 2                                          89275.00000
# 3                                         107793.00000
# 4                                         102278.00000
# ..                                                 ...
# 152                                       216790.00000
# 153                                       260826.00000
# 154                                       235655.91142
# 155                                                NaN
# 156                                                NaN
#
#      Western Canadian Port Activity, Total TEUs_Exports_y.1  \
# 0                                         70230.000000
# 1                                         86567.000000
# 2                                         80451.000000
# 3                                         84739.000000
# 4                                         89548.000000
# ..                                                 ...
# 152                                      103129.000000
# 153                                      105255.000000
# 154                                      102805.965936
# 155                                                NaN
# 156                                                NaN
#
#      Western Canadian Port Activity, Total TEUs_SA Imports_y.1  \
# 0                                         92712.867945
# 1                                        123918.281279
# 2                                        102763.241378
# 3                                        108298.068115
# 4                                        100455.980122
# ..                                                 ...
# 152                                      200875.373073
# 153                                      258626.771977
# 154                                      241663.526867
# 155                                                NaN
# 156                                                NaN
#
#      Total Intermodal (w/o FSC)_y.1  Total Intermodal (w/ FSC)_y.1
# 0                         99.640213                     112.481465
# 1                         99.892838                     112.865989
# 2                        100.466949                     113.715206
# 3                        102.289780                     115.952288
# 4                        102.811441                     117.038513
# ..                              ...                            ...
# 152                      123.509489                     131.952815
# 153                      124.490623                     133.554870
# 154                      125.292560                     134.506167
# 155                             NaN                            NaN
# 156                             NaN                            NaN
#
# [157 rows x 641 columns]

# %%
df = df.drop(df.index[155:157])
df = df.set_index(keys='Year_Month')
df
# Out:
#             Sum of Sales  FTR Truck Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01        381696.51                                      57633.608984
# 2008-02        430305.85                                      57175.659828
# 2008-03        451627.81                                      56814.700553
# 2008-04        467417.48                                      56916.813852
# 2008-05        462676.37                                      56194.246889
# ...                  ...                                               ...
# 2020-07        456579.51                                      61469.059874
# 2020-08        318564.72                                      62140.797176
# 2020-09        980476.36                                      62170.174317
# 2020-10        922901.36                                      62870.759335
# 2020-11        293486.93                                      63237.027387
#
#             FTR Truck Loadings Index (2000=100)_freight_m_trucking  \
# Year_Month
# 2008-01                                            102.678075
# 2008-02                                            101.862208
# 2008-03                                            101.219136
# 2008-04                                            101.401057
# 2008-05                                            100.113756
# ...                                                       ...
# 2020-07                                            109.511184
# 2020-08                                            110.707928
# 2020-09                                            110.760265
# 2020-10                                            112.008404
# 2020-11                                            112.660934
#
#             FTR Active Truck Utilization (%, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                             88.294650
# 2008-02                                             87.998407
# 2008-03                                             87.790155
# 2008-04                                             89.639867
# 2008-05                                             89.134818
# ...                                                       ...
# 2020-07                                             89.962431
# 2020-08                                             90.641835
# 2020-09                                             90.587889
# 2020-10                                             94.367218
# 2020-11                                             95.404858
#
#             Dry Van Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                          18021.824048
# 2008-02                                          17917.808139
# 2008-03                                          17835.922848
# 2008-04                                          17713.172439
# 2008-05                                          17561.485366
# ...                                                       ...
# 2020-07                                          20072.391023
# 2020-08                                          20379.910791
# 2020-09                                          20315.722086
# 2020-10                                          20404.155544
# 2020-11                                          20455.350315
#
#             Reefer Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           3940.638792
# 2008-02                                           3927.115595
# 2008-03                                           3922.853376
# 2008-04                                           3978.633479
# 2008-05                                           3990.692209
# ...                                                       ...
# 2020-07                                           4379.187334
# 2020-08                                           4404.415547
# 2020-09                                           4381.188114
# 2020-10                                           4436.920215
# 2020-11                                           4457.161049
#
#             Flatbed Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           6425.307387
# 2008-02                                           6323.986294
# 2008-03                                           6352.228095
# 2008-04                                           6304.602493
# 2008-05                                           6213.659026
# ...                                                       ...
# 2020-07                                           6993.332683
# 2020-08                                           7096.862705
# 2020-09                                           7049.924576
# 2020-10                                           7199.060314
# 2020-11                                           7260.723423
#
#             Tank Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           6915.782704
# 2008-02                                           6836.939472
# 2008-03                                           6758.129439
# 2008-04                                           6858.428982
# 2008-05                                           6804.610846
# ...                                                       ...
# 2020-07                                           6571.127779
# 2020-08                                           6601.260917
# 2020-09                                           6556.745680
# 2020-10                                           6523.796564
# 2020-11                                           6528.943165
#
#             Bulk Trailer/Straight Truck Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                          22330.056054
# 2008-02                                          22169.810328
# 2008-03                                          21945.566795
# 2008-04                                          22061.976458
# 2008-05                                          21623.799441
# ...                                                       ...
# 2020-07                                          23453.021054
# 2020-08                                          23658.347216
# 2020-09                                          23866.593861
# 2020-10                                          24306.826698
# 2020-11                                          24534.849434
#
#             Food & Kindred Products (000s, SA)_freight_m_trucking  ...  \
# Year_Month                                                         ...
# 2008-01                                           7126.929795      ...
# 2008-02                                           7090.093356      ...
# 2008-03                                           7130.846968      ...
# 2008-04                                           7139.440571      ...
# 2008-05                                           7179.943436      ...
# ...                                                       ...      ...
# 2020-07                                           9375.896057      ...
# 2020-08                                           9520.297567      ...
# 2020-09                                           9472.590699      ...
# 2020-10                                           9565.479621      ...
# 2020-11                                           9612.776202      ...
#
#             East Coast Port Activity, Total TEUs_Exports_y.1  \
# Year_Month
# 2008-01                                        446657.730000
# 2008-02                                        472359.530000
# 2008-03                                        493039.820000
# 2008-04                                        484342.050000
# 2008-05                                        499498.010000
# ...                                                      ...
# 2020-07                                        472910.156297
# 2020-08                                        499597.784894
# 2020-09                                        492325.048120
# 2020-10                                        546879.252290
# 2020-11                                        536326.504108
#
#             East Coast Port Activity, Total TEUs_SA Imports_y.1  \
# Year_Month
# 2008-01                                          5.723749e+05
# 2008-02                                          5.943458e+05
# 2008-03                                          5.561473e+05
# 2008-04                                          5.689482e+05
# 2008-05                                          5.529787e+05
# ...                                                       ...
# 2020-07                                          8.175415e+05
# 2020-08                                          9.441444e+05
# 2020-09                                          9.480849e+05
# 2020-10                                          9.980584e+05
# 2020-11                                          1.030347e+06
#
#             Gulf Coast Port Activity, Total TEUs_Imports_y.1  \
# Year_Month
# 2008-01                                         58486.560000
# 2008-02                                         62079.760000
# 2008-03                                         63169.270000
# 2008-04                                         63221.100000
# 2008-05                                         61657.850000
# ...                                                      ...
# 2020-07                                        131560.759686
# 2020-08                                        150026.806042
# 2020-09                                        156153.318284
# 2020-10                                        173631.303295
# 2020-11                                        157277.954482
#
#             Gulf Coast Port Activity, Total TEUs_Exports_y.1  \
# Year_Month
# 2008-01                                         90322.590000
# 2008-02                                        100410.660000
# 2008-03                                         93384.280000
# 2008-04                                        101642.940000
# 2008-05                                        105424.640000
# ...                                                      ...
# 2020-07                                        125276.157772
# 2020-08                                        125319.157772
# 2020-09                                        117576.128306
# 2020-10                                        123604.184721
# 2020-11                                        130627.239881
#
#             Gulf Coast Port Activity, Total TEUs_SA Imports_y.1  \
# Year_Month
# 2008-01                                          61444.608268
# 2008-02                                          69356.289323
# 2008-03                                          61534.312686
# 2008-04                                          63038.826932
# 2008-05                                          59864.174184
# ...                                                       ...
# 2020-07                                         124175.287958
# 2020-08                                         144616.508568
# 2020-09                                         154165.434806
# 2020-10                                         162787.138608
# 2020-11                                         166005.768833
#
#             Western Canadian Port Activity, Total TEUs_Imports_y.1  \
# Year_Month
# 2008-01                                           97597.00000
# 2008-02                                          105664.00000
# 2008-03                                           89275.00000
# 2008-04                                          107793.00000
# 2008-05                                          102278.00000
# ...                                                       ...
# 2020-07                                          225515.00000
# 2020-08                                          235159.00000
# 2020-09                                          216790.00000
# 2020-10                                          260826.00000
# 2020-11                                          235655.91142
#
#             Western Canadian Port Activity, Total TEUs_Exports_y.1  \
# Year_Month
# 2008-01                                          70230.000000
# 2008-02                                          86567.000000
# 2008-03                                          80451.000000
# 2008-04                                          84739.000000
# 2008-05                                          89548.000000
# ...                                                       ...
# 2020-07                                         103172.000000
# 2020-08                                          93979.000000
# 2020-09                                         103129.000000
# 2020-10                                         105255.000000
# 2020-11                                         102805.965936
#
#             Western Canadian Port Activity, Total TEUs_SA Imports_y.1  \
# Year_Month
# 2008-01                                          92712.867945
# 2008-02                                         123918.281279
# 2008-03                                         102763.241378
# 2008-04                                         108298.068115
# 2008-05                                         100455.980122
# ...                                                       ...
# 2020-07                                         203343.596376
# 2020-08                                         212554.287841
# 2020-09                                         200875.373073
# 2020-10                                         258626.771977
# 2020-11                                         241663.526867
#
#             Total Intermodal (w/o FSC)_y.1  Total Intermodal (w/ FSC)_y.1
# Year_Month
# 2008-01                          99.640213                     112.481465
# 2008-02                          99.892838                     112.865989
# 2008-03                         100.466949                     113.715206
# 2008-04                         102.289780                     115.952288
# 2008-05                         102.811441                     117.038513
# ...                                    ...                            ...
# 2020-07                         119.865470                     128.935612
# 2020-08                         121.915166                     130.511416
# 2020-09                         123.509489                     131.952815
# 2020-10                         124.490623                     133.554870
# 2020-11                         125.292560                     134.506167
#
# [155 rows x 640 columns]

# %% [markdown]
# ### Check whethere there are duplicate columns

# %%
def getDuplicateColumns(df): 
    duplicateColumnNames = set()  
    # Iterate through all the columns  
    # of dataframe 
    for x in range(df.shape[1]):     
        # Take column at xth index. 
        col = df.iloc[:, x] 
        # Iterate through all the columns in 
        # DataFrame from (x + 1)th index to 
        # last index 
        for y in range(x + 1, df.shape[1]): 
            # Take column at yth index. 
            otherCol = df.iloc[:, y] 
            # Check if two columns at x & y 
            # index are equal or not, 
            # if equal then adding  
            # to the set 
            if col.equals(otherCol): 
                duplicateColumnNames.add(df.columns.values[y])      
    # Return list of unique column names  
    # whose contents are duplicates. 
    return list(duplicateColumnNames)

# %%
dups = getDuplicateColumns(df)
dups
# Out:
# ['Intermodal Revenue Movements (IANA-ETSO)_International_x.1',
#  'Gulf Coast Port Activity, Total TEUs_Imports_x.1',
#  'Durable Manufacturing Index_x.1',
#  'ISM Manufacturing Index_x.1',
#  'Total Manufacturing Index_y.1',
#  'USTRADE_driver_indicators_m_trucking',
#  "Payroll Employment (000's)_economics_m_trucking_trailer",
#  'N.A. Port Activity, Total TEUs_Exports_y',
#  'Business Indicators_indicators_m_trucking',
#  'Durable Goods Orders (Mil $)_economics_m_trucking_trailer',
#  'Total Construction Spending (Mil $)_x',
#  'Durable Goods Orders (Mil $)_x.1',
#  'Food Index_x',
#  "Building Permits (000's)_y",
#  "Manufacturing Employment (000's)_x",
#  "New Home Sales (000's)_y",
#  'Chemicals Index_y',
#  "West Coast Port Container Activity (TEU's)_y",
#  'Total Construction Spending (Mil $)_y',
#  "West Coast Port Container Activity (TEU's)_x.1",
#  'Canada Origin Intermodal Volumes_Total_y',
#  'Total Bus. Inventories/Retail Sales Ratio_y',
#  "Manufacturing Employment (000's)_y.1",
#  'UNRATE_driver_indicators_m_trucking',
#  'U.S. Origin Intermodal Volumes_International_y',
#  'S.A. Total Revenue Movements Index (Jan 2001 = 100)_International Movements Index (Jan 2001 = 100)_y.1',
#  'Total Intermodal (w/o FSC)_y',
#  'Mexico Origin Intermodal Volumes_Domestic_y',
#  'Total IP Index_x',
#  'Nondefense Capital Goods Orders (Mil $)_y',
#  'W. Texas Int. Crude Oil ($Bbl.)_y.1',
#  'S.A. Total Revenue Movements Index (Jan 2001 = 100)_Domestic Movements Index (Jan 2001 = 100)_x.1',
#  'Unemployment Rate (%)_y',
#  'W. Texas Int. Crude Oil ($Bbl.)_y',
#  "New Home Sales (000's)_economics_m_trucking_trailer",
#  'Gulf Coast Port Activity, Total TEUs_Exports_y',
#  'Food Index_economics_m_trucking_trailer',
#  "Construction Employment (000's)_x.1",
#  "Building Permits (000's)_x",
#  'N.A. Port Activity, Total TEUs_Imports_y.1',
#  'Employment Data (BLS)_driver_indicators_m_trucking',
#  'N.A. Port Activity, Total TEUs_Exports_y.1',
#  "Construction Employment (000's)_x",
#  'Total IP Index_y.1',
#  "Existing Home Sales (000's)_x",
#  'National Avg. Diesel/Gal._y',
#  'Mexico Origin Intermodal Volumes_International_x.1',
#  'Business Inventories (Mil $)_y',
#  'Less-Than-Truckload (LTL) Rates (rev/ton)_rates_m_trucking',
#  'Western Canadian Port Activity, Total TEUs_Imports_y',
#  'Unemployment Rate (%)_x',
#  'N.A. Port Activity, Total TEUs_Imports_y',
#  'Non-Durable Manufacturing Index_y',
#  'Nondefense Capital Goods Orders (Mil $)_x',
#  'Non-Durable Manufacturing Index_x',
#  'Intermodal Revenue Movements (IANA-ETSO)_Domestic Containers_y',
#  'Western Canadian Port Activity, Total TEUs_Imports_x.1',
#  'Gulf Coast Port Activity, Total TEUs_Imports_y.1',
#  "Payroll Employment (000's)_y.1",
#  "Retail Trade Employment (000's)_x.1",
#  'Interest Rate Spread (%)_economics_m_trucking_trailer',
#  'S&P 500_economics_m_trucking_trailer',
#  'East Coast Port Activity, Total TEUs_Imports_x.1',
#  'Total IP Index_y',
#  'Non-Durable Manufacturing Index_economics_m_trucking_trailer',
#  'Western Canadian Port Activity, Total TEUs_Imports_y.1',
#  'Total Bus. Inventories/Retail Sales Ratio_x',
#  "Total Transp. and Warehouse Emp. (000's)_y.1",
#  "Intermodal Revenue Movements (IANA-ETSO)_Memo: Domestic Containers & 53'+ Trailers_y.1",
#  'Mexico Origin Intermodal Volumes_Total_x.1',
#  'Public Construction Spending (Mil $)_x.1',
#  'Private Non-Residential Construction (Mil $)_x',
#  'East Coast Port Activity, Total TEUs_Exports_y',
#  'West Coast Port Activity, Total TEUs_Imports_x.1',
#  'USCONS_driver_indicators_m_trucking',
#  'West Coast Port Activity, Total TEUs_Exports_y.1',
#  'Distillate Fuel Inventories (Mil Barrels/Day)_y',
#  'Automobile and Light-Duty Vehicles Index_y.1',
#  'Chicago Fed National Activity Index 3MMA_y',
#  'Retail Sales (Mil $)_x.1',
#  'Retail Sales (Mil $)_y.1',
#  'Chemicals Index_economics_m_trucking_trailer',
#  'Public Construction Spending (Mil $)_economics_m_trucking_trailer',
#  'Leading Economic Indicators (%)_x',
#  'Consumer Indicators_indicators_m_trucking',
#  'Total Manufacturing Index_x',
#  'U.S. Origin Intermodal Volumes_Domestic_y',
#  'U.S. Origin Intermodal Volumes_Domestic_x.1',
#  'Total Intermodal (w/ FSC)_y',
#  "Truck Transportation Employment (000's)_x.1",
#  'S&P 500_x.1',
#  'S.A. Total Revenue Movements Index (Jan 2001 = 100)_International Movements Index (Jan 2001 = 100)_y',
#  "Manufacturing Employment (000's)_x.1",
#  "Construction Employment (000's)_y",
#  'W. Texas Int. Crude Oil ($Bbl.)_economics_m_trucking_trailer',
#  "Manufacturing Employment (000's)_y",
#  'Cass Freight Shipments Index (1992=100)_economics_m_trucking_trailer',
#  'N.A. Port Activity, Total TEUs_SA Imports_y.1',
#  'Durable Goods Orders (Mil $)_y',
#  'Business Inventories (Mil $)_x',
#  "Retail Trade Employment (000's)_x",
#  'Total Intermodal (w/o FSC)_y.1',
#  "West Coast Port Container Activity (TEU's)_economics_m_trucking_trailer",
#  "West Coast Port Container Activity (TEU's)_x",
#  'Intermodal Revenue Movements (IANA-ETSO)_Domestic_x.1',
#  'Non-Durable Manufacturing Index_x.1',
#  "Retail Trade Employment (000's)_y.1",
#  'West Coast Port Activity, Total TEUs_Imports_y',
#  'Mexico Origin Intermodal Volumes_Total_y.1',
#  "Existing Home Sales (000's)_x.1",
#  'W. Texas Int. Crude Oil ($Bbl.)_x',
#  'Total Bus. Inventories/Retail Sales Ratio_economics_m_trucking_trailer',
#  'Retail Sales (Mil $)_economics_m_trucking_trailer',
#  'Private Residential Construction (Mil $)_y',
#  "Container Share %, Total Intermodal_Truckload Only % (Dom. Container+53' Trailers)_y",
#  'Intermodal (Rail + Drayage) Rates (rev/load)_rates_m_trucking',
#  'ISM Manufacturing Index_x',
#  'National Avg. Diesel/Gal._x.1',
#  'Retail Sales (Mil $)_y',
#  'Western Canadian Port Activity, Total TEUs_SA Imports_x.1',
#  'Private Non-Residential Construction (Mil $)_y',
#  'Consumer Price Index_x',
#  'West Coast Port Activity, Total TEUs_SA Imports_x.1',
#  'Mexico Origin Intermodal Volumes_Domestic_x.1',
#  'N.A. Port Activity, Total TEUs_SA Imports_y',
#  'Oil & Fuel_indicators_m_trucking',
#  'National Avg. Diesel/Gal._y.1',
#  'TTWEMP_driver_indicators_m_trucking',
#  'Consumer Price Index_x.1',
#  'Cass Freight Shipments Index (1992=100)_y.1',
#  "Existing Home Sales (000's)_economics_m_trucking_trailer",
#  'Fabricated Metal Product Index_economics_m_trucking_trailer',
#  'East Coast Port Activity, Total TEUs_Exports_x.1',
#  'Nondefense Capital Goods Orders (Mil $)_x.1',
#  'TRUCKEMP_driver_indicators_m_trucking',
#  'Consumer Confidence (Conference Board)_x',
#  "Building Permits (000's)_y.1",
#  'Gulf Coast Port Activity, Total TEUs_SA Imports_y.1',
#  'Gulf Coast Port Activity, Total TEUs_SA Imports_y',
#  'FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_y.1',
#  'S.A. Total Revenue Movements Index (Jan 2001 = 100)_International Movements Index (Jan 2001 = 100)_x.1',
#  'Private Residential Construction (Mil $)_economics_m_trucking_trailer',
#  'U.S. Origin Intermodal Volumes_Domestic_y.1',
#  "Other Transportation Employment (000's)_y.1",
#  'Chicago Fed National Activity Index 3MMA_economics_m_trucking_trailer',
#  "Payroll Employment (000's)_y",
#  'West Coast Port Activity, Total TEUs_SA Imports_y',
#  'Total Manufacturing Index_y',
#  'Total Intermodal (w/ FSC)_y.1',
#  'W. Texas Int. Crude Oil ($Bbl.)_x.1',
#  'Total Manufacturing Index_x.1',
#  "Retail Trade Employment (000's)_economics_m_trucking_trailer",
#  'Fabricated Metal Product Index_y',
#  "Housing Starts (000's)_x.1",
#  'Durable Goods Orders (Mil $)_y.1',
#  'East Coast Port Activity, Total TEUs_Imports_y.1',
#  'Consumer Confidence (Conference Board)_economics_m_trucking_trailer',
#  'Chemicals Index_x',
#  'Total IP Index_x.1',
#  'Consumer Confidence (Conference Board)_x.1',
#  'Change in Distillate Fuel Inventories_y',
#  'Distillate Fuel Inventories (Mil Barrels/Day)_x.1',
#  'Interest Rate Spread (%)_y.1',
#  'Total Construction Spending (Mil $)_y.1',
#  'Consumer Price Index_y.1',
#  'National Avg. Diesel/Gal._x',
#  'Total Construction Spending (Mil $)_x.1',
#  'Automobile and Light-Duty Vehicles Index_y',
#  'Total Intermodal (w/o FSC)_x',
#  "Total Transp. and Warehouse Emp. (000's)_y",
#  "Truck Transportation Employment (000's)_x",
#  'West Coast Port Activity, Total TEUs_Exports_y',
#  'Chicago Fed National Activity Index 3MMA_x',
#  'Interest Rate Spread (%)_y',
#  'Intermodal Revenue Movements (IANA-ETSO)_Domestic_y.1',
#  'Retail Sales (Mil $)_x',
#  'Total Construction Spending (Mil $)_economics_m_trucking_trailer',
#  'Consumer Confidence (Conference Board)_y',
#  'U.S. Origin Intermodal Volumes_International_x.1',
#  'Total Bus. Inventories/Retail Sales Ratio_x.1',
#  'Automobile and Light-Duty Vehicles Index_x.1',
#  'Distillate Fuel Inventories (Mil Barrels/Day)_economics_m_trucking_trailer',
#  "Housing Starts (000's)_economics_m_trucking_trailer",
#  'Chicago Fed National Activity Index 3MMA_y.1',
#  'Fabricated Metal Product Index_x.1',
#  'S&P 500_y.1',
#  "Existing Home Sales (000's)_y",
#  "Manufacturing Employment (000's)_economics_m_trucking_trailer",
#  'S&P 500_x',
#  'Private Residential Construction (Mil $)_y.1',
#  'Cass Freight Shipments Index (1992=100)_y',
#  'East Coast Port Activity, Total TEUs_SA Imports_x.1',
#  'Total Intermodal (w/ FSC)_x.1',
#  'Canada Origin Intermodal Volumes_International_y.1',
#  'Western Canadian Port Activity, Total TEUs_SA Imports_y',
#  'N.A. Port Activity, Total TEUs_SA Imports_x.1',
#  'Western Canadian Port Activity, Total TEUs_Exports_y',
#  "Total Transp. and Warehouse Emp. (000's)_x",
#  'Business Inventories (Mil $)_y.1',
#  'ISM Manufacturing Index_y.1',
#  'Unemployment Rate (%)_economics_m_trucking_trailer',
#  'Food Index_x.1',
#  'Industrial Production (2002=100)_indicators_m_trucking',
#  'S&P 500_y',
#  "Construction Employment (000's)_y.1",
#  'Freight & Labor Indices (FTR)_driver_indicators_m_trucking',
#  'Fabricated Metal Product Index_y.1',
#  'Intermodal Revenue Movements (IANA-ETSO)_Domestic Containers_y.1',
#  'S.A. Total Revenue Movements Index (Jan 2001 = 100)_Domestic Movements Index (Jan 2001 = 100)_y.1',
#  'Change in Distillate Fuel Inventories_y.1',
#  'Chemicals Index_x.1',
#  "Truck Transportation Employment (000's)_economics_m_trucking_trailer",
#  "New Home Sales (000's)_y.1",
#  'Automobile and Light-Duty Vehicles Index_x',
#  'East Coast Port Activity, Total TEUs_Imports_y',
#  'Gulf Coast Port Activity, Total TEUs_Exports_x.1',
#  'Distillate Fuel Inventories (Mil Barrels/Day)_y.1',
#  'Change in Distillate Fuel Inventories_x.1',
#  "Other Transportation Employment (000's)_x.1",
#  'Food Index_y',
#  'Intermodal Revenue Movements (IANA-ETSO)_Total_y.1',
#  "Intermodal Revenue Movements (IANA-ETSO)_Memo: Domestic Containers & 53'+ Trailers_x.1",
#  'Consumer Confidence (Conference Board)_y.1',
#  'Public Construction Spending (Mil $)_y',
#  'Private Non-Residential Construction (Mil $)_economics_m_trucking_trailer',
#  'Western Canadian Port Activity, Total TEUs_Exports_x.1',
#  'Intermodal Revenue Movements (IANA-ETSO)_Total_y',
#  'ISM Manufacturing Index_economics_m_trucking_trailer',
#  'Chemicals Index_y.1',
#  'Total Bus. Inventories/Retail Sales Ratio_y.1',
#  'Automobile and Light-Duty Vehicles Index_economics_m_trucking_trailer',
#  "Existing Home Sales (000's)_y.1",
#  'Unemployment Rate (%)_y.1',
#  'Leading Economic Indicators (%)_y',
#  "Total Transp. and Warehouse Emp. (000's)_x.1",
#  'FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_x.1',
#  "Payroll Employment (000's)_x",
#  'Mexico Origin Intermodal Volumes_International_y',
#  'Durable Manufacturing Index_y',
#  'Mexico Origin Intermodal Volumes_Total_y',
#  'Consumer Price Index_economics_m_trucking_trailer',
#  'Nondefense Capital Goods Orders (Mil $)_y.1',
#  'Gulf Coast Port Activity, Total TEUs_Imports_y',
#  "Other Transportation Employment (000's)_x",
#  'Food Index_y.1',
#  'Durable Manufacturing Index_x',
#  'Interest Rate Spread (%)_x.1',
#  'U.S. Origin Intermodal Volumes_Total_x.1',
#  'East Coast Port Activity, Total TEUs_SA Imports_y',
#  "Total Transp. and Warehouse Emp. (000's)_economics_m_trucking_trailer",
#  'Durable Manufacturing Index_economics_m_trucking_trailer',
#  'S.A. Total Revenue Movements Index (Jan 2001 = 100)_Domestic Movements Index (Jan 2001 = 100)_y',
#  'Intermodal Revenue Movements (IANA-ETSO)_Total_x.1',
#  'Canada Origin Intermodal Volumes_Total_x.1',
#  'Non-Durable Manufacturing Index_y.1',
#  'PAYEMS_driver_indicators_m_trucking',
#  'Canada Origin Intermodal Volumes_Total_y.1',
#  'Private Residential Construction (Mil $)_x',
#  'Leading Economic Indicators (%)_y.1',
#  'Heavy-Duty Trucks, North America_indicators_m_trucking',
#  'Container Share %, Total Intermodal_Total Domestic % (Dom. Container+Trailers)_y.1',
#  "West Coast Port Container Activity (TEU's)_y.1",
#  'Western Canadian Port Activity, Total TEUs_Exports_y.1',
#  'Leading Economic Indicators (%)_economics_m_trucking_trailer',
#  'Total Manufacturing Index_economics_m_trucking_trailer',
#  "New Home Sales (000's)_x.1",
#  'Canada Origin Intermodal Volumes_International_y',
#  'Intermodal Revenue Movements (IANA-ETSO)_International_y',
#  'FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_y',
#  "Housing Starts (000's)_y",
#  'N.A. Port Activity, Total TEUs_Exports_x.1',
#  'Public Construction Spending (Mil $)_y.1',
#  'Nondefense Capital Goods Orders (Mil $)_economics_m_trucking_trailer',
#  "Container Share %, Total Intermodal_Truckload Only % (Dom. Container+53' Trailers)_y.1",
#  "Building Permits (000's)_x.1",
#  "Payroll Employment (000's)_x.1",
#  "Building Permits (000's)_economics_m_trucking_trailer",
#  'National Avg. Diesel/Gal._economics_m_trucking_trailer',
#  'Consumer Price Index_y',
#  "Intermodal Revenue Movements (IANA-ETSO)_Memo: Domestic Containers & 53'+ Trailers_y",
#  'West Coast Port Activity, Total TEUs_Exports_x.1',
#  'Public Construction Spending (Mil $)_x',
#  'Private Residential Construction (Mil $)_x.1',
#  'Container Share %, Total Intermodal_Total Domestic % (Dom. Container+Trailers)_y',
#  'U.S. Origin Intermodal Volumes_Total_y',
#  'Total IP Index_economics_m_trucking_trailer',
#  "Housing Starts (000's)_y.1",
#  'ISM Manufacturing Index_y',
#  'Business Inventories (Mil $)_economics_m_trucking_trailer',
#  'Canada Origin Intermodal Volumes_Domestic_y',
#  'Gulf Coast Port Activity, Total TEUs_Exports_y.1',
#  "Container Share %, Total Intermodal_Truckload Only % (Dom. Container+53' Trailers)_x.1",
#  'Intermodal Revenue Movements (IANA-ETSO)_Domestic_y',
#  'Durable Goods Orders (Mil $)_x',
#  "Other Transportation Employment (000's)_y",
#  'MANEMP_driver_indicators_m_trucking',
#  "Other Transportation Employment (000's)_economics_m_trucking_trailer",
#  "Truck Transportation Employment (000's)_y.1",
#  'Unemployment Rate (%)_x.1',
#  'East Coast Port Activity, Total TEUs_Exports_y.1',
#  'Fabricated Metal Product Index_x',
#  'Private Non-Residential Construction (Mil $)_y.1',
#  'Mexico Origin Intermodal Volumes_Domestic_y.1',
#  'West Coast Port Activity, Total TEUs_Imports_y.1',
#  'East Coast Port Activity, Total TEUs_SA Imports_y.1',
#  'Distillate Fuel Inventories (Mil Barrels/Day)_x',
#  "Construction Employment (000's)_economics_m_trucking_trailer",
#  'MEMO: Tank Truckload (TL) Rates (rev/mi)_rates_m_trucking',
#  "New Home Sales (000's)_x",
#  'U.S. Origin Intermodal Volumes_International_y.1',
#  'U.S. Origin Intermodal Volumes_Total_y.1',
#  'Durable Manufacturing Index_y.1',
#  "Retail Trade Employment (000's)_y",
#  'Gulf Coast Port Activity, Total TEUs_SA Imports_x.1',
#  'Western Canadian Port Activity, Total TEUs_SA Imports_y.1',
#  'Leading Economic Indicators (%)_x.1',
#  'Container Share %, Total Intermodal_Total Domestic % (Dom. Container+Trailers)_x.1',
#  "Truck Transportation Employment (000's)_y",
#  'Canada Origin Intermodal Volumes_Domestic_x.1',
#  'N.A. Port Activity, Total TEUs_Imports_x.1',
#  'Intermodal Revenue Movements (IANA-ETSO)_International_y.1',
#  'West Coast Port Activity, Total TEUs_SA Imports_y.1',
#  'Private Non-Residential Construction (Mil $)_x.1',
#  'Intermodal Revenue Movements (IANA-ETSO)_Domestic Containers_x.1',
#  'Cass Freight Shipments Index (1992=100)_x.1',
#  'Canada Origin Intermodal Volumes_International_x.1',
#  'Mexico Origin Intermodal Volumes_International_y.1',
#  'Cass Freight Shipments Index (1992=100)_x',
#  'Total Intermodal (w/o FSC)_x.1',
#  'Canada Origin Intermodal Volumes_Domestic_y.1',
#  'Interest Rate Spread (%)_x',
#  'Chicago Fed National Activity Index 3MMA_x.1',
#  "Housing Starts (000's)_x",
#  'Business Inventories (Mil $)_x.1',
#  'Total Intermodal (w/ FSC)_x']

# %%
df = df.drop(columns=dups)
df
# Out:
#             Sum of Sales  FTR Truck Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01        381696.51                                      57633.608984
# 2008-02        430305.85                                      57175.659828
# 2008-03        451627.81                                      56814.700553
# 2008-04        467417.48                                      56916.813852
# 2008-05        462676.37                                      56194.246889
# ...                  ...                                               ...
# 2020-07        456579.51                                      61469.059874
# 2020-08        318564.72                                      62140.797176
# 2020-09        980476.36                                      62170.174317
# 2020-10        922901.36                                      62870.759335
# 2020-11        293486.93                                      63237.027387
#
#             FTR Truck Loadings Index (2000=100)_freight_m_trucking  \
# Year_Month
# 2008-01                                            102.678075
# 2008-02                                            101.862208
# 2008-03                                            101.219136
# 2008-04                                            101.401057
# 2008-05                                            100.113756
# ...                                                       ...
# 2020-07                                            109.511184
# 2020-08                                            110.707928
# 2020-09                                            110.760265
# 2020-10                                            112.008404
# 2020-11                                            112.660934
#
#             FTR Active Truck Utilization (%, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                             88.294650
# 2008-02                                             87.998407
# 2008-03                                             87.790155
# 2008-04                                             89.639867
# 2008-05                                             89.134818
# ...                                                       ...
# 2020-07                                             89.962431
# 2020-08                                             90.641835
# 2020-09                                             90.587889
# 2020-10                                             94.367218
# 2020-11                                             95.404858
#
#             Dry Van Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                          18021.824048
# 2008-02                                          17917.808139
# 2008-03                                          17835.922848
# 2008-04                                          17713.172439
# 2008-05                                          17561.485366
# ...                                                       ...
# 2020-07                                          20072.391023
# 2020-08                                          20379.910791
# 2020-09                                          20315.722086
# 2020-10                                          20404.155544
# 2020-11                                          20455.350315
#
#             Reefer Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           3940.638792
# 2008-02                                           3927.115595
# 2008-03                                           3922.853376
# 2008-04                                           3978.633479
# 2008-05                                           3990.692209
# ...                                                       ...
# 2020-07                                           4379.187334
# 2020-08                                           4404.415547
# 2020-09                                           4381.188114
# 2020-10                                           4436.920215
# 2020-11                                           4457.161049
#
#             Flatbed Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           6425.307387
# 2008-02                                           6323.986294
# 2008-03                                           6352.228095
# 2008-04                                           6304.602493
# 2008-05                                           6213.659026
# ...                                                       ...
# 2020-07                                           6993.332683
# 2020-08                                           7096.862705
# 2020-09                                           7049.924576
# 2020-10                                           7199.060314
# 2020-11                                           7260.723423
#
#             Tank Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           6915.782704
# 2008-02                                           6836.939472
# 2008-03                                           6758.129439
# 2008-04                                           6858.428982
# 2008-05                                           6804.610846
# ...                                                       ...
# 2020-07                                           6571.127779
# 2020-08                                           6601.260917
# 2020-09                                           6556.745680
# 2020-10                                           6523.796564
# 2020-11                                           6528.943165
#
#             Bulk Trailer/Straight Truck Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                          22330.056054
# 2008-02                                          22169.810328
# 2008-03                                          21945.566795
# 2008-04                                          22061.976458
# 2008-05                                          21623.799441
# ...                                                       ...
# 2020-07                                          23453.021054
# 2020-08                                          23658.347216
# 2020-09                                          23866.593861
# 2020-10                                          24306.826698
# 2020-11                                          24534.849434
#
#             Food & Kindred Products (000s, SA)_freight_m_trucking  ...  \
# Year_Month                                                         ...
# 2008-01                                           7126.929795      ...
# 2008-02                                           7090.093356      ...
# 2008-03                                           7130.846968      ...
# 2008-04                                           7139.440571      ...
# 2008-05                                           7179.943436      ...
# ...                                                       ...      ...
# 2020-07                                           9375.896057      ...
# 2020-08                                           9520.297567      ...
# 2020-09                                           9472.590699      ...
# 2020-10                                           9565.479621      ...
# 2020-11                                           9612.776202      ...
#
#             West Coast Port Activity, Total TEUs_SA Imports_x  \
# Year_Month
# 2008-01                                          8.168066e+05
# 2008-02                                          9.662124e+05
# 2008-03                                          8.138837e+05
# 2008-04                                          8.183477e+05
# 2008-05                                          8.016842e+05
# ...                                                       ...
# 2020-07                                          9.768974e+05
# 2020-08                                          9.985477e+05
# 2020-09                                          9.583687e+05
# 2020-10                                          1.052633e+06
# 2020-11                                          1.031281e+06
#
#             East Coast Port Activity, Total TEUs_Imports_x  \
# Year_Month
# 2008-01                                       5.455093e+05
# 2008-02                                       5.469667e+05
# 2008-03                                       5.478672e+05
# 2008-04                                       5.623923e+05
# 2008-05                                       5.670828e+05
# ...                                                    ...
# 2020-07                                       8.590785e+05
# 2020-08                                       9.981690e+05
# 2020-09                                       9.808289e+05
# 2020-10                                       1.051551e+06
# 2020-11                                       1.005455e+06
#
#             East Coast Port Activity, Total TEUs_Exports_x  \
# Year_Month
# 2008-01                                      446657.730000
# 2008-02                                      472359.530000
# 2008-03                                      493039.820000
# 2008-04                                      484342.050000
# 2008-05                                      499498.010000
# ...                                                    ...
# 2020-07                                      472910.156297
# 2020-08                                      499597.784894
# 2020-09                                      492325.048120
# 2020-10                                      546879.252290
# 2020-11                                      536326.504108
#
#             East Coast Port Activity, Total TEUs_SA Imports_x  \
# Year_Month
# 2008-01                                          5.723749e+05
# 2008-02                                          5.943458e+05
# 2008-03                                          5.561473e+05
# 2008-04                                          5.689482e+05
# 2008-05                                          5.529787e+05
# ...                                                       ...
# 2020-07                                          8.175415e+05
# 2020-08                                          9.441444e+05
# 2020-09                                          9.480849e+05
# 2020-10                                          9.980584e+05
# 2020-11                                          1.030347e+06
#
#             Gulf Coast Port Activity, Total TEUs_Imports_x  \
# Year_Month
# 2008-01                                       58486.560000
# 2008-02                                       62079.760000
# 2008-03                                       63169.270000
# 2008-04                                       63221.100000
# 2008-05                                       61657.850000
# ...                                                    ...
# 2020-07                                      131560.759686
# 2020-08                                      150026.806042
# 2020-09                                      156153.318284
# 2020-10                                      173631.303295
# 2020-11                                      157277.954482
#
#             Gulf Coast Port Activity, Total TEUs_Exports_x  \
# Year_Month
# 2008-01                                       90322.590000
# 2008-02                                      100410.660000
# 2008-03                                       93384.280000
# 2008-04                                      101642.940000
# 2008-05                                      105424.640000
# ...                                                    ...
# 2020-07                                      125276.157772
# 2020-08                                      125319.157772
# 2020-09                                      117576.128306
# 2020-10                                      123604.184721
# 2020-11                                      130627.239881
#
#             Gulf Coast Port Activity, Total TEUs_SA Imports_x  \
# Year_Month
# 2008-01                                          61444.608268
# 2008-02                                          69356.289323
# 2008-03                                          61534.312686
# 2008-04                                          63038.826932
# 2008-05                                          59864.174184
# ...                                                       ...
# 2020-07                                         124175.287958
# 2020-08                                         144616.508568
# 2020-09                                         154165.434806
# 2020-10                                         162787.138608
# 2020-11                                         166005.768833
#
#             Western Canadian Port Activity, Total TEUs_Imports_x  \
# Year_Month
# 2008-01                                           97597.00000
# 2008-02                                          105664.00000
# 2008-03                                           89275.00000
# 2008-04                                          107793.00000
# 2008-05                                          102278.00000
# ...                                                       ...
# 2020-07                                          225515.00000
# 2020-08                                          235159.00000
# 2020-09                                          216790.00000
# 2020-10                                          260826.00000
# 2020-11                                          235655.91142
#
#             Western Canadian Port Activity, Total TEUs_Exports_x  \
# Year_Month
# 2008-01                                          70230.000000
# 2008-02                                          86567.000000
# 2008-03                                          80451.000000
# 2008-04                                          84739.000000
# 2008-05                                          89548.000000
# ...                                                       ...
# 2020-07                                         103172.000000
# 2020-08                                          93979.000000
# 2020-09                                         103129.000000
# 2020-10                                         105255.000000
# 2020-11                                         102805.965936
#
#             Western Canadian Port Activity, Total TEUs_SA Imports_x
# Year_Month
# 2008-01                                          92712.867945
# 2008-02                                         123918.281279
# 2008-03                                         102763.241378
# 2008-04                                         108298.068115
# 2008-05                                         100455.980122
# ...                                                       ...
# 2020-07                                         203343.596376
# 2020-08                                         212554.287841
# 2020-09                                         200875.373073
# 2020-10                                         258626.771977
# 2020-11                                         241663.526867
#
# [155 rows x 305 columns]

# %% [markdown]
# ### Feature Selection

# %%
X = df.drop(columns='Sum of Sales')
X.head()
y = df['Sum of Sales']
y
# Out:
# Year_Month
# 2008-01    381696.51
# 2008-02    430305.85
# 2008-03    451627.81
# 2008-04    467417.48
# 2008-05    462676.37
#              ...
# 2020-07    456579.51
# 2020-08    318564.72
# 2020-09    980476.36
# 2020-10    922901.36
# 2020-11    293486.93
# Name: Sum of Sales, Length: 155, dtype: float64

# %%
fs=FeatureSelector(data=X, labels=y)

# %% [markdown]
# #### Check missing values

# %%
fs.identify_missing(missing_threshold=0)
# Out:
# 94 features with greater than 0.00 missing values.

# %%
fs.ops['missing']
# Out:
# ['Truckload (TL) Rates (rev/mi)_rates_m_trucking',
#  'CASS_indicators_m_trucking',
#  'ISRATIO_indicators_m_trucking',
#  'BUSINV_indicators_m_trucking',
#  'DGO_indicators_m_trucking',
#  'NDCGO_indicators_m_trucking',
#  'CF3M_indicators_m_trucking',
#  'SP500_indicators_m_trucking',
#  'TOTCON_indicators_m_trucking',
#  'PUBCON_indicators_m_trucking',
#  'RESCON_indicators_m_trucking',
#  'NRCON_indicators_m_trucking',
#  'HST_indicators_m_trucking',
#  'BPT_indicators_m_trucking',
#  'NHS_indicators_m_trucking',
#  'EHS_indicators_m_trucking',
#  'Total Class 8, North America_OEM Net Orders_indicators_m_trucking_trailer',
#  'Total Class 8, North America_OEM Net Orders_M/M % Change_indicators_m_trucking_trailer',
#  'Total Class 8, North America_OEM Net Orders_Y/Y % Change_indicators_m_trucking_trailer',
#  'BACKLOG_Total_Trailer',
#  'INVENTORY_Total_Trailer',
#  'NET ORDERS_Total_Trailer',
#  'FACTORY SHIPMENTS_Total_Trailer',
#  'Backlog/ \r\nBuild Ratio_Total_Trailer',
#  'Inventory/Factory Shipments Ratio_Total_Trailer',
#  'BACKLOG_Dry_Van',
#  'INVENTORY_Dry_Van',
#  'NET ORDERS_Dry_Van',
#  'FACTORY SHIPMENTS_Dry_Van',
#  'Backlog/ \r\nBuild Ratio_Dry_Van',
#  'Inventory/Factory Shipments Ratio_Dry_Van',
#  'BACKLOG_Reefer_Van',
#  'INVENTORY_Reefer_Van',
#  'NET ORDERS_Reefer_Van',
#  'FACTORY SHIPMENTS_Reefer_Van',
#  'Backlog/ \r\nBuild Ratio_Reefer_Van',
#  'Inventory/Factory Shipments Ratio_Reefer_Van',
#  'BACKLOG_Flatbed',
#  'INVENTORY_Flatbed',
#  'NET ORDERS_Flatbed',
#  'FACTORY SHIPMENTS_Flatbed',
#  'Backlog/ \r\nBuild Ratio_Flatbed',
#  'Inventory/Factory Shipments Ratio_Flatbed',
#  'BACKLOG_Liquid_Tank',
#  'INVENTORY_Liquid_Tank',
#  'NET ORDERS_Liquid_Tank',
#  'FACTORY SHIPMENTS_Liquid_Tank',
#  'Backlog/ \r\nBuild Ratio_Liquid_Tank',
#  'Inventory/Factory Shipments Ratio_Liquid_Tank',
#  'BACKLOG_Dry_Tank',
#  'INVENTORY_Dry_Tank',
#  'NET ORDERS_Dry_Tank',
#  'FACTORY SHIPMENTS_Dry_Tank',
#  'Backlog/ \r\nBuild Ratio_Dry_Tank',
#  'Inventory/Factory Shipments Ratio_Dry_Tank',
#  'BACKLOG_Dump',
#  'INVENTORY_Dump',
#  'NET ORDERS_Dump',
#  'FACTORY SHIPMENTS_Dump',
#  'Backlog/ \r\nBuild Ratio_Dump',
#  'Inventory/Factory Shipments Ratio_Dump',
#  'BACKLOG_Lowbed',
#  'INVENTORY_Lowbed',
#  'NET ORDERS_Lowbed',
#  'FACTORY SHIPMENTS_Lowbed',
#  'Backlog/ \r\nBuild Ratio_Lowbed',
#  'Inventory/Factory Shipments Ratio_Lowbed',
#  'BACKLOG_All_Other',
#  'INVENTORY_All_Other',
#  'NET ORDERS_All_Other',
#  'FACTORY SHIPMENTS_All_Other',
#  'Backlog/ \r\nBuild Ratio_All_Other',
#  'Inventory/Factory Shipments Ratio_All_Other',
#  'BACKLOG_MEMO_Total_Vans',
#  'INVENTORY_MEMO_Total_Vans',
#  'NET ORDERS_MEMO_Total_Vans',
#  'FACTORY SHIPMENTS_MEMO_Total_Vans',
#  'Backlog/ \r\nBuild Ratio_MEMO_Total_Vans',
#  'Inventory/Factory Shipments Ratio_MEMO_Total_Vans',
#  'BACKLOG_MEMO_Total_Tanks',
#  'INVENTORY_MEMO_Total_Tanks',
#  'NET ORDERS_MEMO_Total_Tanks',
#  'FACTORY SHIPMENTS_MEMO_Total_Tanks',
#  'Backlog/ \r\nBuild Ratio_MEMO_Total_Tanks',
#  'Inventory/Factory Shipments Ratio_MEMO_Total_Tanks',
#  'BACKLOG_MEMO_Major_Voc',
#  'INVENTORY_MEMO_Major_Voc',
#  'NET ORDERS_MEMO_Major_Voc',
#  'FACTORY SHIPMENTS_MEMO_Major_Voc',
#  'Backlog/ \r\nBuild Ratio_MEMO_Major_Voc',
#  'Inventory/Factory Shipments Ratio_MEMO_Major_Voc',
#  'Mexico Origin Intermodal Volumes_International_x',
#  'Mexico Origin Intermodal Volumes_Domestic_x',
#  'Mexico Origin Intermodal Volumes_Total_x']

# %%
fs.plot_missing()

# %% [markdown]
# #### Check Collinearity

# %%
fs.identify_collinear(correlation_threshold=0.95)
# Out:
# 128 features with a correlation magnitude greater than 0.95.

# %%
collinear_features = fs.ops['collinear']
fs.record_collinear.head(20)
# Out:
#                                          drop_feature  \
# 0   FTR Truck Loadings Index (2000=100)_freight_m_...
# 1   Dry Van Trailer Loadings (000s, SA)_freight_m_...
# 2   Dry Van Trailer Loadings (000s, SA)_freight_m_...
# 3   Flatbed Trailer Loadings (000s, SA)_freight_m_...
# 4   Flatbed Trailer Loadings (000s, SA)_freight_m_...
# 5   Flatbed Trailer Loadings (000s, SA)_freight_m_...
# 6   Bulk Trailer/Straight Truck Loadings (000s, SA...
# 7   Bulk Trailer/Straight Truck Loadings (000s, SA...
# 8   Bulk Trailer/Straight Truck Loadings (000s, SA...
# 9   Stone, Clay, Glass & Concrete (000s, SA)_freig...
# 10  Stone, Clay, Glass & Concrete (000s, SA)_freig...
# 11  Stone, Clay, Glass & Concrete (000s, SA)_freig...
# 12  Stone, Clay, Glass & Concrete (000s, SA)_freig...
# 13    All Other Freight (000s, SA)_freight_m_trucking
# 14    All Other Freight (000s, SA)_freight_m_trucking
# 15    All Other Freight (000s, SA)_freight_m_trucking
# 16    All Other Freight (000s, SA)_freight_m_trucking
# 17    All Other Freight (000s, SA)_freight_m_trucking
# 18            Short-Haul (<125 mi)_freight_m_trucking
# 19            Short-Haul (<125 mi)_freight_m_trucking
#
#                                          corr_feature  corr_value
# 0    FTR Truck Loadings (000s, SA)_freight_m_trucking    1.000000
# 1    FTR Truck Loadings (000s, SA)_freight_m_trucking    0.960822
# 2   FTR Truck Loadings Index (2000=100)_freight_m_...    0.960822
# 3    FTR Truck Loadings (000s, SA)_freight_m_trucking    0.994974
# 4   FTR Truck Loadings Index (2000=100)_freight_m_...    0.994974
# 5   Dry Van Trailer Loadings (000s, SA)_freight_m_...    0.957094
# 6    FTR Truck Loadings (000s, SA)_freight_m_trucking    0.992075
# 7   FTR Truck Loadings Index (2000=100)_freight_m_...    0.992075
# 8   Flatbed Trailer Loadings (000s, SA)_freight_m_...    0.988296
# 9    FTR Truck Loadings (000s, SA)_freight_m_trucking    0.971318
# 10  FTR Truck Loadings Index (2000=100)_freight_m_...    0.971318
# 11  Flatbed Trailer Loadings (000s, SA)_freight_m_...    0.974363
# 12  Bulk Trailer/Straight Truck Loadings (000s, SA...    0.974347
# 13   FTR Truck Loadings (000s, SA)_freight_m_trucking    0.988754
# 14  FTR Truck Loadings Index (2000=100)_freight_m_...    0.988754
# 15  Flatbed Trailer Loadings (000s, SA)_freight_m_...    0.980777
# 16  Bulk Trailer/Straight Truck Loadings (000s, SA...    0.977411
# 17  Stone, Clay, Glass & Concrete (000s, SA)_freig...    0.953545
# 18  Stone, Clay, Glass & Concrete (000s, SA)_freig...    0.969600
# 19  Nonmetallic Minerals, Except Fuels (000s, SA)_...    0.959323

# %% [markdown]
# #### Check zero importance features

# %%
fs.identify_zero_importance(task='regression', eval_metric='mse', early_stopping=False)
# Out:
# Training Gradient Boosting Model
#
#
# 42 features with zero importance after one-hot encoding.

# %%
fs.plot_feature_importances(threshold=0.99)
# Out:
# 226 features required for 0.99 of cumulative importance

# %% [markdown]
# #### Check Low Importance Features

# %%
fs.identify_low_importance(cumulative_importance=0.35)
fs.feature_importances.head(20)
# Out:
# 17 features required for cumulative importance of 0.35 after one hot encoding.
# 287 features do not contribute to cumulative importance of 0.35.
#                                               feature  importance  \
# 0             Change in Distillate Fuel Inventories_x       351.0
# 1   Total Class 8, North America_OEM Net Orders_M/...       264.0
# 2   FTR Truck Loadings_M/M % Change_freight_m_truc...       121.0
# 3   FTR Rail Carloadings_M/M % Change_freight_m_tr...       116.0
# 4                           NHS_indicators_m_trucking       113.0
# 5   FTR Cl. 8 Truck Tonmiles__Y/Y % Change_freight...        92.0
# 6   FTR Rail Carloadings (carload + intermodal) (0...        82.0
# 7   Food & Kindred Products (000s, SA)_freight_m_t...        80.0
# 8   FTR MD Truck Tonnage_Y/Y % Change_freight_m_tr...        79.0
# 9        Super Long-Haul (550+ mi)_freight_m_trucking        76.0
# 10  FTR Cl. 8 Truck Tonnage_M/M % Change_freight_m...        70.0
# 11  Total Class 8, North America_Retail Sales (War...        70.0
# 12  Total Trailers, U.S._Production_M/M % Change_i...        66.0
# 13                                 INVENTORY_Dry_Tank        65.0
# 14  Change in Total Transp. Emp. (000's)_driver_in...        65.0
# 15  FTR Rail Intermodal Loadings_M/M % Change_frei...        65.0
# 16  Total Classes 4-7, North America_Inventories (...        63.0
# 17  Food & Kindred Products (000s, SA)_freight_m_t...        63.0
# 18  Total Class 8, North America_OEM Net Orders_in...        63.0
# 19  Total Trailers, U.S._Production_Y/Y % Change_i...        63.0
#
#     normalized_importance  cumulative_importance
# 0                0.065681               0.065681
# 1                0.049401               0.115082
# 2                0.022642               0.137725
# 3                0.021707               0.159431
# 4                0.021145               0.180576
# 5                0.017216               0.197792
# 6                0.015344               0.213136
# 7                0.014970               0.228106
# 8                0.014783               0.242889
# 9                0.014222               0.257111
# 10               0.013099               0.270210
# 11               0.013099               0.283308
# 12               0.012350               0.295659
# 13               0.012163               0.307822
# 14               0.012163               0.319985
# 15               0.012163               0.332148
# 16               0.011789               0.343937
# 17               0.011789               0.355726
# 18               0.011789               0.367515
# 19               0.011789               0.379304

# %% [markdown]
# #### Remove features

# %%
feature_selected = fs.remove(methods=['missing','collinear','zero_importance','low_importance'])
features = np.append(list(['Sum of Sales']),list(feature_selected.columns))
df = df[features]
df
# Out:
# Removed 292 features.
#             Sum of Sales  \
# Year_Month
# 2008-01        381696.51
# 2008-02        430305.85
# 2008-03        451627.81
# 2008-04        467417.48
# 2008-05        462676.37
# ...                  ...
# 2020-07        456579.51
# 2020-08        318564.72
# 2020-09        980476.36
# 2020-10        922901.36
# 2020-11        293486.93
#
#             Food & Kindred Products (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           7126.929795
# 2008-02                                           7090.093356
# 2008-03                                           7130.846968
# 2008-04                                           7139.440571
# 2008-05                                           7179.943436
# ...                                                       ...
# 2020-07                                           9375.896057
# 2020-08                                           9520.297567
# 2020-09                                           9472.590699
# 2020-10                                           9565.479621
# 2020-11                                           9612.776202
#
#             Super Long-Haul (550+ mi)_freight_m_trucking  \
# Year_Month
# 2008-01                                      6351.102588
# 2008-02                                      6306.556660
# 2008-03                                      6261.756219
# 2008-04                                      6271.352278
# 2008-05                                      6275.163788
# ...                                                  ...
# 2020-07                                      6240.013431
# 2020-08                                      6312.982923
# 2020-09                                      6258.050709
# 2020-10                                      6333.545023
# 2020-11                                      6365.044238
#
#             Change in Total Transp. Emp. (000's)_driver_indicators_m_trucking  \
# Year_Month
# 2008-01                                                   2.0
# 2008-02                                                   4.0
# 2008-03                                                   0.0
# 2008-04                                                   5.0
# 2008-05                                                 -12.0
# ...                                                       ...
# 2020-07                                                  48.0
# 2020-08                                                  85.0
# 2020-09                                                  44.0
# 2020-10                                                  62.0
# 2020-11                                                 145.0
#
#             Total Class 8, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer  \
# Year_Month
# 2008-01                                             17.711599
# 2008-02                                            -21.096509
# 2008-03                                             12.451390
# 2008-04                                             -9.859063
# 2008-05                                              3.365907
# ...                                                       ...
# 2020-07                                            -25.612015
# 2020-08                                            -20.398412
# 2020-09                                             46.491376
# 2020-10                                              6.538928
# 2020-11                                             16.397616
#
#             Total Trailers, U.S._Production_M/M % Change_indicators_m_trucking_trailer  \
# Year_Month
# 2008-01                                            -10.826287
# 2008-02                                            -16.623657
# 2008-03                                             -6.406104
# 2008-04                                            -20.856725
# 2008-05                                             14.177437
# ...                                                       ...
# 2020-07                                            -33.586799
# 2020-08                                             13.435626
# 2020-09                                             17.536391
# 2020-10                                            -11.888071
# 2020-11                                              6.968110
#
#             Total Classes 4-7, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer  \
# Year_Month
# 2008-01                                             -5.728404
# 2008-02                                              2.197078
# 2008-03                                             -6.795043
# 2008-04                                             -3.430210
# 2008-05                                              5.186474
# ...                                                       ...
# 2020-07                                            -12.877938
# 2020-08                                             -7.676672
# 2020-09                                              3.496257
# 2020-10                                              1.187032
# 2020-11                                              2.356025
#
#             FTR Truck Loadings_M/M % Change_freight_m_trucking_trailer  \
# Year_Month
# 2008-01                                             -2.749882
# 2008-02                                              0.590421
# 2008-03                                              0.963854
# 2008-04                                             -0.014003
# 2008-05                                             -0.794587
# ...                                                       ...
# 2020-07                                            -11.868303
# 2020-08                                              3.278161
# 2020-09                                              5.879324
# 2020-10                                              2.427460
# 2020-11                                              1.092806
#
#             FTR Rail Intermodal Loadings_M/M % Change_freight_m_trucking_trailer  \
# Year_Month
# 2008-01                                             -1.855190
# 2008-02                                              1.841867
# 2008-03                                              0.682647
# 2008-04                                             -2.911224
# 2008-05                                              3.273510
# ...                                                       ...
# 2020-07                                            -12.597259
# 2020-08                                              4.534112
# 2020-09                                             10.985691
# 2020-10                                              6.261749
# 2020-11                                              1.040215
#
#             FTR Rail Carloadings (carload + intermodal) (000s, SA)_freight_m_trucking_trailer  \
# Year_Month
# 2008-01                                           3093.638815
# 2008-02                                           3167.478461
# 2008-03                                           3164.474988
# 2008-04                                           2955.033944
# 2008-05                                           3059.748460
# ...                                                       ...
# 2020-07                                           2202.067829
# 2020-08                                           2185.585205
# 2020-09                                           2400.291965
# 2020-10                                           2619.082565
# 2020-11                                           2647.393281
#
#             FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer  \
# Year_Month
# 2008-01                                              1.794564
# 2008-02                                              2.386822
# 2008-03                                             -0.094822
# 2008-04                                             -6.618508
# 2008-05                                              3.543598
# ...                                                       ...
# 2020-07                                            -14.351778
# 2020-08                                             -0.748507
# 2020-09                                              9.823765
# 2020-10                                              9.115166
# 2020-11                                              1.080940
#
#             FTR Cl. 8 Truck Tonnage_M/M % Change_freight_m_trucking_trailer  \
# Year_Month
# 2008-01                                             -3.537698
# 2008-02                                              0.994483
# 2008-03                                              1.500016
# 2008-04                                             -0.384513
# 2008-05                                             -0.798424
# ...                                                       ...
# 2020-07                                             -8.401269
# 2020-08                                              0.733856
# 2020-09                                              1.478794
# 2020-10                                              3.304924
# 2020-11                                              0.830824
#
#             Change in Distillate Fuel Inventories_x
# Year_Month
# 2008-01                                     -2981.0
# 2008-02                                    -13327.0
# 2008-03                                     -9852.0
# 2008-04                                      -733.0
# 2008-05                                      6890.0
# ...                                             ...
# 2020-07                                      2134.0
# 2020-08                                      1353.0
# 2020-09                                     -7196.0
# 2020-10                                    -10130.4
# 2020-11                                    -16121.6
#
# [155 rows x 13 columns]

# %%
#df.to_csv('Pack_ext_fs.csv')

# %%
# %matplotlib inline
import pandas as pd # for using pandas daraframe
import numpy as np # for som math operations
from sklearn.preprocessing import StandardScaler # for standardizing the Data
from sklearn.decomposition import PCA # for PCA calculation
import matplotlib.pyplot as plt # for plotting

# %%
features = df.loc[:, df.columns != 'Sum of Sales']
features
# Out:
#             FTR Truck Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                         57633.608984
# 2008-02                                         57175.659828
# 2008-03                                         56814.700553
# 2008-04                                         56916.813852
# 2008-05                                         56194.246889
# ...                                                      ...
# 2020-07                                         61469.059874
# 2020-08                                         62140.797176
# 2020-09                                         62170.174317
# 2020-10                                         62870.759335
# 2020-11                                         63237.027387
#
#             FTR Active Truck Utilization (%, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                             88.294650
# 2008-02                                             87.998407
# 2008-03                                             87.790155
# 2008-04                                             89.639867
# 2008-05                                             89.134818
# ...                                                       ...
# 2020-07                                             89.962431
# 2020-08                                             90.641835
# 2020-09                                             90.587889
# 2020-10                                             94.367218
# 2020-11                                             95.404858
#
#             Reefer Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           3940.638792
# 2008-02                                           3927.115595
# 2008-03                                           3922.853376
# 2008-04                                           3978.633479
# 2008-05                                           3990.692209
# ...                                                       ...
# 2020-07                                           4379.187334
# 2020-08                                           4404.415547
# 2020-09                                           4381.188114
# 2020-10                                           4436.920215
# 2020-11                                           4457.161049
#
#             Tank Trailer Loadings (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           6915.782704
# 2008-02                                           6836.939472
# 2008-03                                           6758.129439
# 2008-04                                           6858.428982
# 2008-05                                           6804.610846
# ...                                                       ...
# 2020-07                                           6571.127779
# 2020-08                                           6601.260917
# 2020-09                                           6556.745680
# 2020-10                                           6523.796564
# 2020-11                                           6528.943165
#
#             Chemicals & Allied Products (000s, SA)_freight_m_trucking  \
# Year_Month
# 2008-01                                           3013.868684
# 2008-02                                           2975.285847
# 2008-03                                           2941.079313
# 2008-04                                           2906.591249
# 2008-05                                           2872.185063
# ...                                                       ...
# 2020-07                                           2639.040651
# 2020-08                                           2676.666422
# 2020-09                                           2600.808117
# 2020-10                                           2593.200335
# 2020-11                                           2589.965347
#
#             Spot TL Rates (w/o FSC)_rates_m_trucking  \
# Year_Month
# 2008-01                                    96.932289
# 2008-02                                    99.719858
# 2008-03                                   103.347853
# 2008-04                                   111.718085
# 2008-05                                   117.525703
# ...                                              ...
# 2020-07                                   115.128696
# 2020-08                                   129.107598
# 2020-09                                   136.100117
# 2020-10                                   140.122763
# 2020-11                                   138.706256
#
#             Contract TL Rates w/Fuel_rates_m_trucking  \
# Year_Month
# 2008-01                                    112.305447
# 2008-02                                    112.181182
# 2008-03                                    111.302493
# 2008-04                                    110.502609
# 2008-05                                    110.767343
# ...                                               ...
# 2020-07                                    137.122933
# 2020-08                                    139.852134
# 2020-09                                    141.491235
# 2020-10                                    144.369645
# 2020-11                                    147.077783
#
#             Total LTL (w/ FSC)_rates_m_trucking  \
# Year_Month
# 2008-01                              114.408275
# 2008-02                              114.867841
# 2008-03                              117.070858
# 2008-04                              122.811123
# 2008-05                              123.968232
# ...                                         ...
# 2020-07                              113.578198
# 2020-08                              115.812566
# 2020-09                              117.464895
# 2020-10                              117.793788
# 2020-11                              119.272026
#
#             Contract TL Tank Rates (w/o FSC)_rates_m_trucking  \
# Year_Month
# 2008-01                                             99.995901
# 2008-02                                            100.276486
# 2008-03                                             99.727612
# 2008-04                                             99.057287
# 2008-05                                             97.828232
# ...                                                       ...
# 2020-07                                            115.191063
# 2020-08                                            114.911925
# 2020-09                                            115.470202
# 2020-10                                            115.098017
# 2020-11                                            116.095115
#
#             OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking  ...  \
# Year_Month                                                            ...
# 2008-01                                               16185.0         ...
# 2008-02                                               11091.0         ...
# 2008-03                                               14647.0         ...
# 2008-04                                               14264.0         ...
# 2008-05                                               12060.0         ...
# ...                                                       ...         ...
# 2020-07                                               19213.0         ...
# 2020-08                                               18302.0         ...
# 2020-09                                               28766.0         ...
# 2020-10                                               36912.0         ...
# 2020-11                                               49818.0         ...
#
#             BUILD FOR_All_Other  Change in Distillate Fuel Inventories_x  \
# Year_Month
# 2008-01                   969.0                                  -2981.0
# 2008-02                  1104.0                                 -13327.0
# 2008-03                  1158.0                                  -9852.0
# 2008-04                   931.0                                   -733.0
# 2008-05                   991.0                                   6890.0
# ...                         ...                                      ...
# 2020-07                  1359.0                                   2134.0
# 2020-08                  1671.0                                   1353.0
# 2020-09                  1711.0                                  -7196.0
# 2020-10                  2018.0                                 -10130.4
# 2020-11                  1601.0                                 -16121.6
#
#             Intermodal Revenue Movements (IANA-ETSO)_Total_x  \
# Year_Month
# 2008-01                                            1156094.0
# 2008-02                                            1088826.0
# 2008-03                                            1082825.0
# 2008-04                                            1158286.0
# 2008-05                                            1184144.0
# ...                                                      ...
# 2020-07                                            1526490.0
# 2020-08                                            1575928.0
# 2020-09                                            1617044.0
# 2020-10                                            1705714.0
# 2020-11                                            1565892.0
#
#             FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_x  \
# Year_Month
# 2008-01                                              3.341993
# 2008-02                                              2.285576
# 2008-03                                              1.924076
# 2008-04                                              5.986521
# 2008-05                                              7.940801
# ...                                                       ...
# 2020-07                                             -0.192121
# 2020-08                                              0.625716
# 2020-09                                              5.475578
# 2020-10                                              9.817290
# 2020-11                                              8.110988
#
#             U.S. Origin Intermodal Volumes_International_x  \
# Year_Month
# 2008-01                                           557011.0
# 2008-02                                           501961.0
# 2008-03                                           481100.0
# 2008-04                                           528843.0
# 2008-05                                           541259.0
# ...                                                    ...
# 2020-07                                           513074.0
# 2020-08                                           546740.0
# 2020-09                                           557748.0
# 2020-10                                           591616.0
# 2020-11                                           554324.0
#
#             Canada Origin Intermodal Volumes_Domestic_x  \
# Year_Month
# 2008-01                                         46969.0
# 2008-02                                         44924.0
# 2008-03                                         46727.0
# 2008-04                                         53497.0
# 2008-05                                         53653.0
# ...                                                 ...
# 2020-07                                         57503.0
# 2020-08                                         56478.0
# 2020-09                                         59269.0
# 2020-10                                         60708.0
# 2020-11                                         57649.0
#
#             N.A. Port Activity, Total TEUs_Exports_x  \
# Year_Month
# 2008-01                                 1.035742e+06
# 2008-02                                 1.138045e+06
# 2008-03                                 1.167742e+06
# 2008-04                                 1.156788e+06
# 2008-05                                 1.185090e+06
# ...                                              ...
# 2020-07                                 1.095134e+06
# 2020-08                                 1.108304e+06
# 2020-09                                 1.099329e+06
# 2020-10                                 1.186353e+06
# 2020-11                                 1.135686e+06
#
#             West Coast Port Activity, Total TEUs_Exports_x  \
# Year_Month
# 2008-01                                      428531.270000
# 2008-02                                      478707.330000
# 2008-03                                      500866.450000
# 2008-04                                      486063.840000
# 2008-05                                      490618.980000
# ...                                                    ...
# 2020-07                                      393775.832112
# 2020-08                                      389408.103791
# 2020-09                                      386298.700253
# 2020-10                                      410614.677268
# 2020-11                                      365926.096985
#
#             Gulf Coast Port Activity, Total TEUs_Exports_x  \
# Year_Month
# 2008-01                                       90322.590000
# 2008-02                                      100410.660000
# 2008-03                                       93384.280000
# 2008-04                                      101642.940000
# 2008-05                                      105424.640000
# ...                                                    ...
# 2020-07                                      125276.157772
# 2020-08                                      125319.157772
# 2020-09                                      117576.128306
# 2020-10                                      123604.184721
# 2020-11                                      130627.239881
#
#             Western Canadian Port Activity, Total TEUs_Exports_x
# Year_Month
# 2008-01                                          70230.000000
# 2008-02                                          86567.000000
# 2008-03                                          80451.000000
# 2008-04                                          84739.000000
# 2008-05                                          89548.000000
# ...                                                       ...
# 2020-07                                         103172.000000
# 2020-08                                          93979.000000
# 2020-09                                         103129.000000
# 2020-10                                         105255.000000
# 2020-11                                         102805.965936
#
# [155 rows x 71 columns]

# %%
df.dropna(axis = 1, inplace = True)
X = features.values # getting all values as a matrix of dataframe 
sc = StandardScaler() # creating a StandardScaler object
X_std = sc.fit_transform(X) # standardizing the data

# %%
pca = PCA(n_components = 0.99)
X_pca = pca.fit_transform(X_std) # this will fit and reduce dimensions
print(pca.n_components_) # one can print and see how many components are selected. In this case it is 4 same as above we saw in step 5
# Out:
# 42

# %%
pd.DataFrame(pca.components_, columns = features.columns)
# Out:
#     FTR Truck Loadings (000s, SA)_freight_m_trucking  \
# 0                                          -0.159018
# 1                                           0.191703
# 2                                           0.029437
# 3                                           0.127313
# 4                                          -0.030250
# 5                                          -0.066300
# 6                                          -0.000944
# 7                                          -0.012508
# 8                                          -0.027965
# 9                                          -0.034282
# 10                                         -0.015598
# 11                                          0.013899
# 12                                         -0.021297
# 13                                         -0.017257
# 14                                          0.047704
# 15                                         -0.000358
# 16                                          0.009776
# 17                                         -0.008923
# 18                                          0.089632
# 19                                          0.040290
# 20                                          0.030974
# 21                                         -0.058835
# 22                                         -0.012778
# 23                                          0.005891
# 24                                         -0.072915
# 25                                         -0.001680
# 26                                          0.001877
# 27                                          0.013029
# 28                                         -0.011019
# 29                                          0.037255
# 30                                          0.024266
# 31                                         -0.079822
# 32                                          0.023005
# 33                                         -0.014593
# 34                                          0.021202
# 35                                         -0.019550
# 36                                         -0.081436
# 37                                          0.034064
# 38                                          0.011698
# 39                                          0.088546
# 40                                          0.046810
# 41                                         -0.001457
#
#     FTR Active Truck Utilization (%, SA)_freight_m_trucking  \
# 0                                           -0.068650
# 1                                            0.011804
# 2                                           -0.168065
# 3                                            0.290670
# 4                                            0.058639
# 5                                           -0.195403
# 6                                           -0.042052
# 7                                           -0.197407
# 8                                           -0.017447
# 9                                            0.040434
# 10                                          -0.026331
# 11                                          -0.103127
# 12                                           0.086086
# 13                                          -0.107983
# 14                                           0.150327
# 15                                          -0.020635
# 16                                           0.031771
# 17                                           0.088760
# 18                                           0.075957
# 19                                          -0.010356
# 20                                          -0.000762
# 21                                          -0.107001
# 22                                          -0.090782
# 23                                          -0.077246
# 24                                          -0.058008
# 25                                           0.116744
# 26                                           0.028500
# 27                                           0.061890
# 28                                           0.189209
# 29                                           0.069512
# 30                                          -0.020001
# 31                                          -0.041957
# 32                                          -0.007071
# 33                                          -0.017861
# 34                                           0.006100
# 35                                           0.010344
# 36                                           0.032027
# 37                                          -0.034430
# 38                                           0.003979
# 39                                           0.113226
# 40                                          -0.034520
# 41                                          -0.069033
#
#     Reefer Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                           -0.060952
# 1                                            0.224330
# 2                                            0.012654
# 3                                            0.220200
# 4                                            0.063365
# 5                                           -0.156614
# 6                                           -0.026144
# 7                                            0.105982
# 8                                           -0.147177
# 9                                           -0.010868
# 10                                           0.019967
# 11                                           0.028001
# 12                                          -0.057034
# 13                                          -0.147035
# 14                                           0.093838
# 15                                          -0.002326
# 16                                           0.037128
# 17                                           0.108611
# 18                                           0.018502
# 19                                           0.013341
# 20                                           0.037366
# 21                                          -0.006327
# 22                                           0.030122
# 23                                          -0.049612
# 24                                          -0.035962
# 25                                           0.026683
# 26                                           0.030228
# 27                                          -0.093695
# 28                                           0.059150
# 29                                           0.030779
# 30                                           0.022527
# 31                                           0.036884
# 32                                          -0.056926
# 33                                          -0.094659
# 34                                           0.075529
# 35                                           0.033681
# 36                                          -0.025247
# 37                                           0.085074
# 38                                          -0.145939
# 39                                           0.269896
# 40                                           0.107906
# 41                                          -0.025371
#
#     Tank Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                           -0.032831
# 1                                            0.241159
# 2                                           -0.097487
# 3                                            0.077660
# 4                                            0.116083
# 5                                           -0.161567
# 6                                           -0.086487
# 7                                            0.096983
# 8                                           -0.154921
# 9                                            0.001315
# 10                                          -0.020370
# 11                                           0.014396
# 12                                          -0.111877
# 13                                          -0.112438
# 14                                           0.114342
# 15                                          -0.045126
# 16                                          -0.055155
# 17                                           0.138003
# 18                                          -0.036516
# 19                                          -0.030857
# 20                                          -0.041999
# 21                                          -0.120840
# 22                                          -0.113789
# 23                                           0.126129
# 24                                           0.101324
# 25                                          -0.092475
# 26                                          -0.152939
# 27                                           0.017947
# 28                                           0.021954
# 29                                          -0.278951
# 30                                           0.202467
# 31                                           0.178890
# 32                                          -0.004301
# 33                                          -0.083844
# 34                                          -0.104136
# 35                                          -0.207194
# 36                                          -0.110912
# 37                                          -0.146812
# 38                                           0.170907
# 39                                          -0.130201
# 40                                          -0.049796
# 41                                          -0.001730
#
#     Chemicals & Allied Products (000s, SA)_freight_m_trucking  \
# 0                                           -0.010068
# 1                                            0.157195
# 2                                           -0.217177
# 3                                            0.115806
# 4                                            0.146958
# 5                                           -0.222789
# 6                                           -0.045787
# 7                                            0.196411
# 8                                           -0.108104
# 9                                           -0.050383
# 10                                          -0.080564
# 11                                          -0.061511
# 12                                           0.009182
# 13                                           0.000564
# 14                                          -0.016313
# 15                                          -0.024854
# 16                                           0.030701
# 17                                           0.109563
# 18                                           0.039971
# 19                                          -0.030326
# 20                                           0.049628
# 21                                          -0.089113
# 22                                          -0.068185
# 23                                          -0.098376
# 24                                           0.168150
# 25                                          -0.011579
# 26                                           0.061097
# 27                                          -0.151988
# 28                                          -0.009209
# 29                                          -0.055540
# 30                                           0.086650
# 31                                           0.019012
# 32                                           0.078120
# 33                                          -0.026110
# 34                                          -0.084904
# 35                                           0.042036
# 36                                           0.044861
# 37                                           0.115565
# 38                                           0.059213
# 39                                           0.139523
# 40                                          -0.005128
# 41                                           0.030556
#
#     Spot TL Rates (w/o FSC)_rates_m_trucking  \
# 0                                  -0.154333
# 1                                   0.044379
# 2                                  -0.138315
# 3                                   0.050476
# 4                                  -0.000835
# 5                                   0.005087
# 6                                   0.019394
# 7                                  -0.023474
# 8                                   0.161223
# 9                                   0.148566
# 10                                  0.254304
# 11                                  0.060817
# 12                                 -0.032985
# 13                                 -0.100525
# 14                                  0.075706
# 15                                  0.224838
# 16                                  0.188452
# 17                                 -0.062824
# 18                                  0.007414
# 19                                  0.081411
# 20                                  0.008441
# 21                                 -0.012698
# 22                                 -0.008544
# 23                                 -0.030854
# 24                                 -0.144204
# 25                                  0.141587
# 26                                  0.085937
# 27                                 -0.107822
# 28                                 -0.054634
# 29                                  0.096542
# 30                                  0.133064
# 31                                  0.055273
# 32                                  0.013904
# 33                                 -0.110348
# 34                                 -0.011581
# 35                                 -0.009156
# 36                                 -0.182184
# 37                                 -0.101346
# 38                                 -0.269598
# 39                                  0.057601
# 40                                 -0.252027
# 41                                 -0.163603
#
#     Contract TL Rates w/Fuel_rates_m_trucking  \
# 0                                   -0.172438
# 1                                    0.001655
# 2                                    0.105991
# 3                                    0.075749
# 4                                   -0.010763
# 5                                   -0.087269
# 6                                    0.086554
# 7                                    0.223077
# 8                                    0.056695
# 9                                    0.019086
# 10                                   0.132380
# 11                                  -0.031497
# 12                                   0.064102
# 13                                   0.069250
# 14                                   0.150741
# 15                                  -0.012754
# 16                                  -0.138561
# 17                                   0.054500
# 18                                  -0.035183
# 19                                   0.039371
# 20                                  -0.018703
# 21                                   0.021255
# 22                                   0.043991
# 23                                   0.089475
# 24                                   0.018663
# 25                                  -0.080296
# 26                                  -0.037292
# 27                                  -0.045529
# 28                                  -0.087871
# 29                                   0.000778
# 30                                   0.014226
# 31                                  -0.023940
# 32                                   0.048292
# 33                                   0.052321
# 34                                   0.052372
# 35                                  -0.063976
# 36                                   0.128254
# 37                                  -0.015424
# 38                                  -0.073110
# 39                                  -0.112233
# 40                                  -0.104169
# 41                                   0.029375
#
#     Total LTL (w/ FSC)_rates_m_trucking  \
# 0                             -0.139621
# 1                              0.145496
# 2                             -0.114336
# 3                             -0.123120
# 4                             -0.003411
# 5                             -0.013234
# 6                              0.059171
# 7                              0.181758
# 8                              0.122415
# 9                              0.061707
# 10                             0.031502
# 11                             0.127016
# 12                             0.082498
# 13                             0.007584
# 14                             0.130204
# 15                             0.055589
# 16                             0.002093
# 17                             0.154555
# 18                             0.012806
# 19                             0.043223
# 20                            -0.026788
# 21                             0.057726
# 22                             0.125405
# 23                            -0.116179
# 24                            -0.066823
# 25                            -0.131632
# 26                             0.100711
# 27                             0.005102
# 28                            -0.034870
# 29                             0.096252
# 30                            -0.035432
# 31                             0.024621
# 32                            -0.104803
# 33                            -0.167482
# 34                             0.031882
# 35                             0.056221
# 36                             0.109540
# 37                             0.034557
# 38                            -0.179516
# 39                            -0.065376
# 40                            -0.005580
# 41                            -0.064821
#
#     Contract TL Tank Rates (w/o FSC)_rates_m_trucking  \
# 0                                           -0.122854
# 1                                            0.214719
# 2                                            0.071452
# 3                                            0.047630
# 4                                            0.022227
# 5                                           -0.070065
# 6                                            0.043998
# 7                                            0.221882
# 8                                           -0.031295
# 9                                           -0.011359
# 10                                           0.121911
# 11                                           0.083399
# 12                                          -0.029907
# 13                                           0.112126
# 14                                          -0.025519
# 15                                           0.038762
# 16                                          -0.045474
# 17                                          -0.001083
# 18                                           0.005880
# 19                                           0.051695
# 20                                           0.022678
# 21                                           0.110604
# 22                                           0.012810
# 23                                           0.025746
# 24                                          -0.005544
# 25                                          -0.063813
# 26                                          -0.030043
# 27                                          -0.039214
# 28                                          -0.121647
# 29                                           0.068009
# 30                                          -0.046864
# 31                                          -0.059705
# 32                                           0.094567
# 33                                           0.057408
# 34                                           0.013759
# 35                                          -0.045944
# 36                                          -0.096579
# 37                                           0.026246
# 38                                          -0.116903
# 39                                           0.008198
# 40                                          -0.056938
# 41                                           0.058057
#
#     OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking  ...  \
# 0                                           -0.113699         ...
# 1                                           -0.043058         ...
# 2                                           -0.091281         ...
# 3                                            0.120058         ...
# 4                                           -0.053312         ...
# 5                                           -0.046545         ...
# 6                                           -0.002712         ...
# 7                                           -0.081064         ...
# 8                                            0.118492         ...
# 9                                            0.080921         ...
# 10                                           0.423984         ...
# 11                                          -0.200357         ...
# 12                                           0.019867         ...
# 13                                           0.056542         ...
# 14                                           0.000791         ...
# 15                                           0.123787         ...
# 16                                           0.067139         ...
# 17                                          -0.081565         ...
# 18                                           0.100175         ...
# 19                                           0.264710         ...
# 20                                          -0.109329         ...
# 21                                           0.173451         ...
# 22                                           0.283952         ...
# 23                                           0.100308         ...
# 24                                           0.071116         ...
# 25                                           0.053535         ...
# 26                                           0.019807         ...
# 27                                           0.056131         ...
# 28                                           0.312421         ...
# 29                                          -0.376344         ...
# 30                                           0.030057         ...
# 31                                           0.072504         ...
# 32                                          -0.023965         ...
# 33                                           0.063432         ...
# 34                                           0.088055         ...
# 35                                          -0.022786         ...
# 36                                          -0.003590         ...
# 37                                           0.116524         ...
# 38                                           0.135308         ...
# 39                                          -0.037005         ...
# 40                                           0.123890         ...
# 41                                           0.078216         ...
#
#     BUILD FOR_All_Other  Change in Distillate Fuel Inventories_x  \
# 0             -0.166847                                 0.020961
# 1             -0.087261                                 0.025977
# 2              0.037071                                 0.120828
# 3              0.019837                                -0.070531
# 4             -0.038877                                 0.141085
# 5              0.031471                                -0.030802
# 6             -0.050889                                -0.067010
# 7              0.036933                                -0.015898
# 8             -0.114462                                 0.086958
# 9              0.023624                                 0.387170
# 10             0.104902                                -0.158366
# 11             0.151599                                 0.036240
# 12            -0.071799                                -0.055281
# 13            -0.152321                                 0.530203
# 14            -0.093922                                 0.316006
# 15            -0.158100                                -0.105728
# 16            -0.118545                                 0.210244
# 17             0.027627                                -0.146801
# 18            -0.148729                                -0.125379
# 19            -0.158621                                -0.032924
# 20             0.042920                                -0.040211
# 21             0.059258                                -0.193713
# 22             0.257565                                -0.160907
# 23             0.184987                                 0.152969
# 24             0.127321                                -0.050946
# 25             0.105455                                 0.063669
# 26             0.063066                                 0.169005
# 27             0.075722                                 0.029025
# 28             0.147351                                 0.117252
# 29             0.009609                                -0.222555
# 30            -0.058944                                -0.036821
# 31            -0.068661                                -0.031237
# 32             0.218458                                 0.104904
# 33            -0.499337                                -0.050261
# 34            -0.109989                                -0.178227
# 35             0.342926                                 0.094740
# 36             0.165562                                -0.006138
# 37            -0.014110                                 0.023272
# 38            -0.057047                                -0.089694
# 39             0.094779                                 0.095714
# 40            -0.026777                                -0.003084
# 41            -0.078088                                 0.013123
#
#     Intermodal Revenue Movements (IANA-ETSO)_Total_x  \
# 0                                          -0.187946
# 1                                           0.051986
# 2                                           0.069897
# 3                                           0.129727
# 4                                          -0.064101
# 5                                           0.034791
# 6                                           0.024717
# 7                                          -0.046935
# 8                                           0.064172
# 9                                           0.081585
# 10                                          0.032073
# 11                                          0.067952
# 12                                          0.046402
# 13                                         -0.034919
# 14                                         -0.115195
# 15                                         -0.015280
# 16                                          0.026999
# 17                                         -0.032923
# 18                                         -0.120854
# 19                                         -0.089614
# 20                                         -0.019517
# 21                                          0.021150
# 22                                          0.017349
# 23                                          0.058629
# 24                                          0.024351
# 25                                          0.053041
# 26                                         -0.007908
# 27                                          0.005178
# 28                                          0.056075
# 29                                          0.011538
# 30                                          0.014181
# 31                                         -0.031355
# 32                                          0.063639
# 33                                          0.157491
# 34                                          0.016552
# 35                                          0.005871
# 36                                          0.004450
# 37                                         -0.083447
# 38                                          0.016614
# 39                                         -0.070446
# 40                                          0.123766
# 41                                         -0.003092
#
#     FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_x  \
# 0                                           -0.010953
# 1                                           -0.188651
# 2                                           -0.250185
# 3                                            0.085112
# 4                                           -0.056540
# 5                                            0.003092
# 6                                            0.007463
# 7                                           -0.005883
# 8                                            0.148933
# 9                                            0.022120
# 10                                           0.078510
# 11                                          -0.046639
# 12                                           0.156270
# 13                                          -0.093070
# 14                                          -0.029672
# 15                                           0.163344
# 16                                           0.088837
# 17                                          -0.112172
# 18                                          -0.014520
# 19                                           0.022432
# 20                                          -0.060774
# 21                                          -0.007534
# 22                                          -0.339047
# 23                                           0.015026
# 24                                           0.129652
# 25                                           0.202876
# 26                                          -0.219169
# 27                                           0.023519
# 28                                          -0.078646
# 29                                          -0.012907
# 30                                          -0.047698
# 31                                           0.119100
# 32                                          -0.257896
# 33                                          -0.034040
# 34                                          -0.159533
# 35                                           0.108909
# 36                                           0.259551
# 37                                          -0.055989
# 38                                          -0.183193
# 39                                           0.100251
# 40                                           0.009595
# 41                                          -0.012194
#
#     U.S. Origin Intermodal Volumes_International_x  \
# 0                                        -0.179919
# 1                                         0.013932
# 2                                        -0.081723
# 3                                         0.036941
# 4                                         0.024367
# 5                                         0.026398
# 6                                        -0.033261
# 7                                        -0.061889
# 8                                         0.044622
# 9                                         0.131678
# 10                                       -0.060109
# 11                                        0.229726
# 12                                        0.133828
# 13                                        0.022975
# 14                                       -0.223096
# 15                                        0.002927
# 16                                       -0.008475
# 17                                        0.019701
# 18                                       -0.107077
# 19                                       -0.107008
# 20                                       -0.023666
# 21                                       -0.079976
# 22                                       -0.083636
# 23                                        0.042821
# 24                                        0.046559
# 25                                       -0.039985
# 26                                        0.011945
# 27                                        0.039627
# 28                                        0.006465
# 29                                        0.120504
# 30                                        0.156995
# 31                                        0.165722
# 32                                        0.020166
# 33                                        0.099498
# 34                                        0.005220
# 35                                        0.018701
# 36                                        0.016591
# 37                                       -0.088371
# 38                                        0.156685
# 39                                       -0.128469
# 40                                        0.104012
# 41                                       -0.302284
#
#     Canada Origin Intermodal Volumes_Domestic_x  \
# 0                                     -0.174773
# 1                                      0.010694
# 2                                     -0.055646
# 3                                      0.027895
# 4                                     -0.045081
# 5                                      0.031172
# 6                                      0.065843
# 7                                     -0.123648
# 8                                      0.095129
# 9                                      0.115018
# 10                                    -0.083365
# 11                                     0.217363
# 12                                     0.096515
# 13                                    -0.149307
# 14                                    -0.099202
# 15                                     0.123290
# 16                                     0.065723
# 17                                     0.172410
# 18                                    -0.017190
# 19                                     0.049869
# 20                                     0.029284
# 21                                    -0.066652
# 22                                    -0.101577
# 23                                    -0.120744
# 24                                     0.057001
# 25                                     0.035439
# 26                                     0.027425
# 27                                    -0.022174
# 28                                     0.106253
# 29                                    -0.050542
# 30                                     0.039273
# 31                                     0.131472
# 32                                     0.273080
# 33                                     0.056207
# 34                                    -0.353529
# 35                                    -0.015295
# 36                                    -0.160914
# 37                                    -0.078232
# 38                                    -0.040156
# 39                                    -0.130926
# 40                                     0.171674
# 41                                     0.350540
#
#     N.A. Port Activity, Total TEUs_Exports_x  \
# 0                                  -0.145515
# 1                                  -0.077299
# 2                                  -0.086033
# 3                                   0.053899
# 4                                  -0.054105
# 5                                  -0.094429
# 6                                   0.262438
# 7                                   0.081508
# 8                                   0.105698
# 9                                  -0.032269
# 10                                 -0.255714
# 11                                 -0.025596
# 12                                 -0.102265
# 13                                 -0.013022
# 14                                 -0.108574
# 15                                 -0.075549
# 16                                  0.066909
# 17                                 -0.094678
# 18                                 -0.074741
# 19                                 -0.061352
# 20                                 -0.053429
# 21                                  0.192839
# 22                                  0.021513
# 23                                  0.031159
# 24                                 -0.020604
# 25                                 -0.048750
# 26                                  0.028655
# 27                                  0.118075
# 28                                  0.127400
# 29                                 -0.086622
# 30                                 -0.120865
# 31                                  0.061779
# 32                                  0.087271
# 33                                  0.088840
# 34                                 -0.011849
# 35                                 -0.033393
# 36                                 -0.069142
# 37                                 -0.106395
# 38                                 -0.121530
# 39                                  0.098889
# 40                                 -0.008123
# 41                                  0.028897
#
#     West Coast Port Activity, Total TEUs_Exports_x  \
# 0                                        -0.012498
# 1                                        -0.115397
# 2                                        -0.235975
# 3                                        -0.001158
# 4                                        -0.023391
# 5                                        -0.101121
# 6                                         0.240975
# 7                                         0.079118
# 8                                         0.122923
# 9                                        -0.026978
# 10                                       -0.350561
# 11                                       -0.114413
# 12                                        0.075775
# 13                                       -0.058270
# 14                                        0.010762
# 15                                       -0.149231
# 16                                        0.193181
# 17                                       -0.016631
# 18                                       -0.093103
# 19                                       -0.015285
# 20                                        0.002406
# 21                                        0.111462
# 22                                        0.151942
# 23                                       -0.004984
# 24                                        0.022679
# 25                                       -0.082100
# 26                                       -0.107254
# 27                                        0.104625
# 28                                        0.041510
# 29                                       -0.114062
# 30                                       -0.031563
# 31                                       -0.178680
# 32                                        0.180272
# 33                                       -0.077766
# 34                                        0.253523
# 35                                       -0.130924
# 36                                       -0.045787
# 37                                        0.029176
# 38                                       -0.056111
# 39                                        0.119456
# 40                                        0.126111
# 41                                        0.009539
#
#     Gulf Coast Port Activity, Total TEUs_Exports_x  \
# 0                                        -0.140100
# 1                                         0.100859
# 2                                         0.103537
# 3                                         0.098802
# 4                                        -0.067157
# 5                                        -0.076269
# 6                                         0.172028
# 7                                         0.163630
# 8                                        -0.031147
# 9                                        -0.051968
# 10                                       -0.095139
# 11                                        0.041112
# 12                                       -0.189762
# 13                                        0.022991
# 14                                       -0.092663
# 15                                        0.044433
# 16                                       -0.050362
# 17                                       -0.029760
# 18                                        0.067047
# 19                                       -0.103575
# 20                                       -0.105469
# 21                                        0.121659
# 22                                       -0.093318
# 23                                        0.016622
# 24                                       -0.028669
# 25                                       -0.007388
# 26                                        0.272283
# 27                                        0.426933
# 28                                        0.131757
# 29                                        0.005793
# 30                                       -0.047871
# 31                                        0.169261
# 32                                       -0.197667
# 33                                        0.286933
# 34                                       -0.087889
# 35                                        0.042856
# 36                                        0.082633
# 37                                       -0.004943
# 38                                        0.000226
# 39                                       -0.070459
# 40                                       -0.029745
# 41                                       -0.209910
#
#     Western Canadian Port Activity, Total TEUs_Exports_x
# 0                                           -0.150172
# 1                                           -0.026324
# 2                                            0.112605
# 3                                            0.087225
# 4                                           -0.038551
# 5                                           -0.076582
# 6                                            0.150854
# 7                                            0.025918
# 8                                            0.167504
# 9                                           -0.022090
# 10                                          -0.156114
# 11                                          -0.085634
# 12                                          -0.133758
# 13                                           0.035183
# 14                                          -0.039668
# 15                                          -0.106426
# 16                                           0.057087
# 17                                           0.034240
# 18                                           0.014150
# 19                                          -0.047239
# 20                                          -0.118167
# 21                                           0.245951
# 22                                          -0.024399
# 23                                           0.081181
# 24                                          -0.130570
# 25                                           0.017581
# 26                                          -0.227019
# 27                                          -0.567549
# 28                                           0.002113
# 29                                           0.059301
# 30                                          -0.196062
# 31                                           0.050147
# 32                                          -0.156491
# 33                                          -0.013097
# 34                                          -0.237140
# 35                                           0.206923
# 36                                          -0.151718
# 37                                          -0.040218
# 38                                           0.212193
# 39                                           0.002750
# 40                                          -0.056625
# 41                                          -0.095636
#
# [42 rows x 71 columns]

# %%
n_pcs= pca.n_components_ # get number of component
n_pcs
# Out:
# 42

# %%
# get the index of the most important feature on EACH component
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

# %%
initial_feature_names = features.columns
# get the most important feature names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

# %%
most_important_names
# Out:
# ['BUILD FOR_Total_Trailer',
#  "Class 4, North America_Inventories (Ward's)_indicators_m_trucking_trailer",
#  'G325_indicators_m_trucking',
#  'FTR Active Truck Utilization (%, SA)_freight_m_trucking',
#  "Change in Payroll Employment (000's)_driver_indicators_m_trucking",
#  "Total Classes 4-7, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  "Total Class 8, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'FTR Truck Loadings_Y/Y % Change_freight_m_trucking_trailer',
#  "Total Class 8, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'Change in Distillate Fuel Inventories_x',
#  'OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking',
#  'FTR Rail Intermodal Loadings_Y/Y % Change_freight_m_trucking_trailer',
#  "Class 6-7 Bus, North America_Factory Shipments (Ward's)_indicators_m_trucking_trailer",
#  'Change in Distillate Fuel Inventories_x',
#  'FTR Truck Loadings_M/M % Change_freight_m_trucking_trailer',
#  "Total Classes 4-7, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer',
#  'FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer',
#  "Total Class 8, North America_Factory Shipments (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'Total Trailers, U.S._Production_M/M % Change_indicators_m_trucking_trailer',
#  "Total Classes 4-7, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer',
#  'FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_x',
#  'Total Trailers, U.S._Production_M/M % Change_indicators_m_trucking_trailer',
#  "Total Class 8, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'FTR Rail Intermodal Loadings_M/M % Change_freight_m_trucking_trailer',
#  'LEI_indicators_m_trucking',
#  'Western Canadian Port Activity, Total TEUs_Exports_x',
#  'FTR Rail Intermodal Loadings_M/M % Change_freight_m_trucking_trailer',
#  'OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking',
#  "Total Classes 4-7, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer",
#  'FTR Rail Carloadings (carload + intermodal) (000s, SA)_freight_m_trucking_trailer',
#  "Change in Truck Emp. (000's)_driver_indicators_m_trucking",
#  'BUILD FOR_All_Other',
#  'PORTEU_indicators_m_trucking',
#  'BUILD FOR_All_Other',
#  "Change in Truck Emp. (000's)_driver_indicators_m_trucking",
#  "Total Classes 4-7, North America_Factory Shipments (Ward's)_Y/Y % Change_indicators_m_trucking_trailer",
#  'Total Trailers, U.S._Production_Y/Y % Change_indicators_m_trucking_trailer',
#  "Class 4, North America_Factory Shipments (Ward's)_indicators_m_trucking_trailer",
#  "Total Classes 4-7, North America_Factory Shipments (Ward's)_Y/Y % Change_indicators_m_trucking_trailer",
#  'Canada Origin Intermodal Volumes_Domestic_x']

# %%
finalDF = df[['Sum of Sales',
    'BUILD FOR_Total_Trailer',
 "Class 4, North America_Inventories (Ward's)_indicators_m_trucking_trailer",
 'G325_indicators_m_trucking',
 'FTR Active Truck Utilization (%, SA)_freight_m_trucking',
 "Change in Payroll Employment (000's)_driver_indicators_m_trucking",
 "Total Classes 4-7, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 "Total Class 8, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'FTR Truck Loadings_Y/Y % Change_freight_m_trucking_trailer',
 "Total Class 8, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'Change in Distillate Fuel Inventories_x',
 'OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking',
 'FTR Rail Intermodal Loadings_Y/Y % Change_freight_m_trucking_trailer',
 "Class 6-7 Bus, North America_Factory Shipments (Ward's)_indicators_m_trucking_trailer",
 'Change in Distillate Fuel Inventories_x',
 'FTR Truck Loadings_M/M % Change_freight_m_trucking_trailer',
 "Total Classes 4-7, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer',
 'FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer',
 "Total Class 8, North America_Factory Shipments (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'Total Trailers, U.S._Production_M/M % Change_indicators_m_trucking_trailer',
 "Total Classes 4-7, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'FTR Rail Carloadings_M/M % Change_freight_m_trucking_trailer',
 'FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_x',
 'Total Trailers, U.S._Production_M/M % Change_indicators_m_trucking_trailer',
 "Total Class 8, North America_Inventories (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'FTR Rail Intermodal Loadings_M/M % Change_freight_m_trucking_trailer',
 'LEI_indicators_m_trucking',
 'Western Canadian Port Activity, Total TEUs_Exports_x',
 'FTR Rail Intermodal Loadings_M/M % Change_freight_m_trucking_trailer',
 'OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking',
 "Total Classes 4-7, North America_Retail Sales (Ward's)_M/M % Change_indicators_m_trucking_trailer",
 'FTR Rail Carloadings (carload + intermodal) (000s, SA)_freight_m_trucking_trailer',
 "Change in Truck Emp. (000's)_driver_indicators_m_trucking",
 'BUILD FOR_All_Other',
 'PORTEU_indicators_m_trucking',
 'BUILD FOR_All_Other',
 "Change in Truck Emp. (000's)_driver_indicators_m_trucking",
 "Total Classes 4-7, North America_Factory Shipments (Ward's)_Y/Y % Change_indicators_m_trucking_trailer",
 'Total Trailers, U.S._Production_Y/Y % Change_indicators_m_trucking_trailer',
 "Class 4, North America_Factory Shipments (Ward's)_indicators_m_trucking_trailer",
 "Total Classes 4-7, North America_Factory Shipments (Ward's)_Y/Y % Change_indicators_m_trucking_trailer",
 'Canada Origin Intermodal Volumes_Domestic_x']]

# %%
finalDF.to_csv('pack_ext_fs.csv')
