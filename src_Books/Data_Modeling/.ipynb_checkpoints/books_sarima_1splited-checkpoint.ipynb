# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
import pandas as pd
import statsmodels.api as sm
import matplotlib

from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
 
from itertools import product
from tqdm import tqdm_notebook

import Model_Evaluation as me

# %%
#books = pd.read_csv('/Users/rahulnair/Desktop/Labelmaster_/Sales_Data/Books_ext_fs.csv')
#books = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LabelMaster/LabelMaster Data/Books_ext.csv')
books = pd.read_csv('C:/Users/11602/OneDrive/Practicum/LabelMaster_Sales_Forecasting/data/Books_ext_fs.csv')
sales = books[['Year_Month','Sum of Sales']]
sales['Sum of Sales'] = sales['Sum of Sales']/100000
sales
# Out:
#     Year_Month  Sum of Sales
# 0      2008-01      2.826041
# 1      2008-02      2.624744
# 2      2008-03      3.260597
# 3      2008-04      2.153875
# 4      2008-05      4.995599
# ..         ...           ...
# 150    2020-07      1.503481
# 151    2020-08      1.560669
# 152    2020-09      4.687110
# 153    2020-10     11.184468
# 154    2020-11      4.291668
#
# [155 rows x 2 columns]

# %%
books = books.dropna(axis = 1)
exog = books.iloc[:,2:]
exog
# Out:
#      FTR Truck Loadings (000s, SA)_freight_m_trucking  \
# 0                                        57633.608984
# 1                                        57175.659828
# 2                                        56814.700553
# 3                                        56916.813852
# 4                                        56194.246889
# ..                                                ...
# 150                                      61469.059874
# 151                                      62140.797176
# 152                                      62170.174317
# 153                                      62870.759335
# 154                                      63237.027387
#
#      FTR Active Truck Utilization (%, SA)_freight_m_trucking  \
# 0                                            88.294650
# 1                                            87.998407
# 2                                            87.790155
# 3                                            89.639867
# 4                                            89.134818
# ..                                                 ...
# 150                                          89.962431
# 151                                          90.641835
# 152                                          90.587889
# 153                                          94.367218
# 154                                          95.404858
#
#      Reefer Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                          3940.638792
# 1                                          3927.115595
# 2                                          3922.853376
# 3                                          3978.633479
# 4                                          3990.692209
# ..                                                 ...
# 150                                        4379.187334
# 151                                        4404.415547
# 152                                        4381.188114
# 153                                        4436.920215
# 154                                        4457.161049
#
#      Tank Trailer Loadings (000s, SA)_freight_m_trucking  \
# 0                                          6915.782704
# 1                                          6836.939472
# 2                                          6758.129439
# 3                                          6858.428982
# 4                                          6804.610846
# ..                                                 ...
# 150                                        6571.127779
# 151                                        6601.260917
# 152                                        6556.745680
# 153                                        6523.796564
# 154                                        6528.943165
#
#      Chemicals & Allied Products (000s, SA)_freight_m_trucking  \
# 0                                          3013.868684
# 1                                          2975.285847
# 2                                          2941.079313
# 3                                          2906.591249
# 4                                          2872.185063
# ..                                                 ...
# 150                                        2639.040651
# 151                                        2676.666422
# 152                                        2600.808117
# 153                                        2593.200335
# 154                                        2589.965347
#
#      Spot TL Rates (w/o FSC)_rates_m_trucking  \
# 0                                   96.932289
# 1                                   99.719858
# 2                                  103.347853
# 3                                  111.718085
# 4                                  117.525703
# ..                                        ...
# 150                                115.128696
# 151                                129.107598
# 152                                136.100117
# 153                                140.122763
# 154                                138.706256
#
#      Total LTL (w/o FSC)_rates_m_trucking  \
# 0                               99.755501
# 1                               99.755501
# 2                              100.488998
# 3                              101.589242
# 4                              101.314181
# ..                                    ...
# 150                            102.231051
# 151                            104.339853
# 152                            105.898533
# 153                            106.265281
# 154                            107.591849
#
#      Total LTL (w/ FSC)_rates_m_trucking  \
# 0                             114.408275
# 1                             114.867841
# 2                             117.070858
# 3                             122.811123
# 4                             123.968232
# ..                                   ...
# 150                           113.578198
# 151                           115.812566
# 152                           117.464895
# 153                           117.793788
# 154                           119.272026
#
#      Contract TL Tank Rates (w/o FSC)_rates_m_trucking  \
# 0                                            99.995901
# 1                                           100.276486
# 2                                            99.727612
# 3                                            99.057287
# 4                                            97.828232
# ..                                                 ...
# 150                                         115.191063
# 151                                         114.911925
# 152                                         115.470202
# 153                                         115.098017
# 154                                         116.095115
#
#      OEM Net Orders (U.S. / CAN, units)_indicators_m_trucking  ...  \
# 0                                              16185.0         ...
# 1                                              11091.0         ...
# 2                                              14647.0         ...
# 3                                              14264.0         ...
# 4                                              12060.0         ...
# ..                                                 ...         ...
# 150                                            19213.0         ...
# 151                                            18302.0         ...
# 152                                            28766.0         ...
# 153                                            36912.0         ...
# 154                                            49818.0         ...
#
#      BUILD FOR_All_Other  Change in Distillate Fuel Inventories_x  \
# 0                  969.0                                  -2981.0
# 1                 1104.0                                 -13327.0
# 2                 1158.0                                  -9852.0
# 3                  931.0                                   -733.0
# 4                  991.0                                   6890.0
# ..                   ...                                      ...
# 150               1359.0                                   2134.0
# 151               1671.0                                   1353.0
# 152               1711.0                                  -7196.0
# 153               2018.0                                 -10130.4
# 154               1601.0                                 -16121.6
#
#      Intermodal Revenue Movements (IANA-ETSO)_Total_x  \
# 0                                           1156094.0
# 1                                           1088826.0
# 2                                           1082825.0
# 3                                           1158286.0
# 4                                           1184144.0
# ..                                                ...
# 150                                         1526490.0
# 151                                         1575928.0
# 152                                         1617044.0
# 153                                         1705714.0
# 154                                         1565892.0
#
#      FTR Intermodal Competitive Index_Intermodal Competitive Index (0=Neutral)_x  \
# 0                                             3.341993
# 1                                             2.285576
# 2                                             1.924076
# 3                                             5.986521
# 4                                             7.940801
# ..                                                 ...
# 150                                          -0.192121
# 151                                           0.625716
# 152                                           5.475578
# 153                                           9.817290
# 154                                           8.110988
#
#      U.S. Origin Intermodal Volumes_International_x  \
# 0                                          557011.0
# 1                                          501961.0
# 2                                          481100.0
# 3                                          528843.0
# 4                                          541259.0
# ..                                              ...
# 150                                        513074.0
# 151                                        546740.0
# 152                                        557748.0
# 153                                        591616.0
# 154                                        554324.0
#
#      Canada Origin Intermodal Volumes_Domestic_x  \
# 0                                        46969.0
# 1                                        44924.0
# 2                                        46727.0
# 3                                        53497.0
# 4                                        53653.0
# ..                                           ...
# 150                                      57503.0
# 151                                      56478.0
# 152                                      59269.0
# 153                                      60708.0
# 154                                      57649.0
#
#      N.A. Port Activity, Total TEUs_Exports_x  \
# 0                                1.035742e+06
# 1                                1.138045e+06
# 2                                1.167742e+06
# 3                                1.156788e+06
# 4                                1.185090e+06
# ..                                        ...
# 150                              1.095134e+06
# 151                              1.108304e+06
# 152                              1.099329e+06
# 153                              1.186353e+06
# 154                              1.135686e+06
#
#      West Coast Port Activity, Total TEUs_Exports_x  \
# 0                                     428531.270000
# 1                                     478707.330000
# 2                                     500866.450000
# 3                                     486063.840000
# 4                                     490618.980000
# ..                                              ...
# 150                                   393775.832112
# 151                                   389408.103791
# 152                                   386298.700253
# 153                                   410614.677268
# 154                                   365926.096985
#
#      Gulf Coast Port Activity, Total TEUs_Exports_x  \
# 0                                      90322.590000
# 1                                     100410.660000
# 2                                      93384.280000
# 3                                     101642.940000
# 4                                     105424.640000
# ..                                              ...
# 150                                   125276.157772
# 151                                   125319.157772
# 152                                   117576.128306
# 153                                   123604.184721
# 154                                   130627.239881
#
#      Western Canadian Port Activity, Total TEUs_Exports_x
# 0                                         70230.000000
# 1                                         86567.000000
# 2                                         80451.000000
# 3                                         84739.000000
# 4                                         89548.000000
# ..                                                 ...
# 150                                      103172.000000
# 151                                       93979.000000
# 152                                      103129.000000
# 153                                      105255.000000
# 154                                      102805.965936
#
# [155 rows x 70 columns]

# %%
train,test = train_test_split(sales, test_size=0.075, random_state=60616, shuffle=False)

# %%
test
# Out:
#     Year_Month  Sum of Sales
# 143    2019-12      5.255255
# 144    2020-01      5.733124
# 145    2020-02      2.894873
# 146    2020-03      2.462465
# 147    2020-04      2.193816
# 148    2020-05      1.286718
# 149    2020-06      1.367123
# 150    2020-07      1.503481
# 151    2020-08      1.560669
# 152    2020-09      4.687110
# 153    2020-10     11.184468
# 154    2020-11      4.291668

# %%
plt.figure(figsize=[15,8])
plt.plot(train['Year_Month'],train['Sum of Sales'])
plt.title('Monthly Sum of Sales of Books Department')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
ad_fuller_result = adfuller(train['Sum of Sales'])
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -7.448654278403226
# p-value: 5.74799439008589e-11

# %% [markdown]
# Since the p-value is greater than 0.5, we cannot reject null hypothesis and must assume that the series is not stationary.

# %% [markdown]
# sales['sales_diffed'] = sales['Sum of Sales'].diff(1)
# sales

# %% [markdown]
# ad_fuller_result = adfuller(sales['sales_diffed'][1:])
# print(f'ADF Statistic: {ad_fuller_result[0]}')
# print(f'p-value: {ad_fuller_result[1]}')

# %%
fig, ax = plt.subplots(2,1, figsize= (12,8))
fig = sm.graphics.tsa.plot_acf(train['Sum of Sales'], lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(train['Sum of Sales'], lags=50, ax=ax[1])
plt.show()

# %% [markdown]
# # New Section

# %%
p = [0,1,2]
d = [0,1]
q = [0,1,2]
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

df = pd.DataFrame()
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train['Sum of Sales'],
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}- AIC:{}'.format(param, param_seasonal, results.aic))

            combo = [(param,param_seasonal,results.aic)]
            df = df.append(combo)
            print(" ")
        except:
            continue
df.columns = ['param','param_seasonal', 'AIC']
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)- AIC:712.6590773987396
#
# ARIMA(0, 0, 0)x(0, 0, 1, 12)- AIC:580.3062668287193
#
# ARIMA(0, 0, 0)x(0, 0, 2, 12)- AIC:488.3641005452841
#
# ARIMA(0, 0, 0)x(0, 1, 0, 12)- AIC:481.12364971319266
#
# ARIMA(0, 0, 0)x(0, 1, 1, 12)- AIC:379.03703372530606
#
# ARIMA(0, 0, 0)x(0, 1, 2, 12)- AIC:339.5448161428717
#
# ARIMA(0, 0, 0)x(1, 0, 0, 12)- AIC:475.2460975480659
#
# ARIMA(0, 0, 0)x(1, 0, 1, 12)- AIC:435.8919047178209
#
# ARIMA(0, 0, 0)x(1, 0, 2, 12)- AIC:385.7020322976681
#
# ARIMA(0, 0, 0)x(1, 1, 0, 12)- AIC:382.10106022911896
#
# ARIMA(0, 0, 0)x(1, 1, 1, 12)- AIC:378.56487526516645
#
# ARIMA(0, 0, 0)x(1, 1, 2, 12)- AIC:330.8369583858164
#
# ARIMA(0, 0, 0)x(2, 0, 0, 12)- AIC:383.74711891985856
#
# ARIMA(0, 0, 0)x(2, 0, 1, 12)- AIC:383.28386247842275
#
# ARIMA(0, 0, 0)x(2, 0, 2, 12)- AIC:373.93318450505365
#
# ARIMA(0, 0, 0)x(2, 1, 0, 12)- AIC:344.29717654928186
#
# ARIMA(0, 0, 0)x(2, 1, 1, 12)- AIC:346.2969426698123
#
# ARIMA(0, 0, 0)x(2, 1, 2, 12)- AIC:332.71469039390587
#
# ARIMA(0, 0, 1)x(0, 0, 0, 12)- AIC:608.598525500077
#
# ARIMA(0, 0, 1)x(0, 0, 1, 12)- AIC:504.6908083603799
#
# ARIMA(0, 0, 1)x(0, 0, 2, 12)- AIC:446.0700083104655
#
# ARIMA(0, 0, 1)x(0, 1, 0, 12)- AIC:462.6843663955766
#
# ARIMA(0, 0, 1)x(0, 1, 1, 12)- AIC:363.6696400391528
#
# ARIMA(0, 0, 1)x(0, 1, 2, 12)- AIC:324.80803922907126
#
# ARIMA(0, 0, 1)x(1, 0, 0, 12)- AIC:454.9070254419436
#
# ARIMA(0, 0, 1)x(1, 0, 1, 12)- AIC:418.69552588055944
#
# ARIMA(0, 0, 1)x(1, 0, 2, 12)- AIC:373.8301879946874
#
# ARIMA(0, 0, 1)x(1, 1, 0, 12)- AIC:374.4173259498122
#
# ARIMA(0, 0, 1)x(1, 1, 1, 12)- AIC:366.850981409279
#
# ARIMA(0, 0, 1)x(1, 1, 2, 12)- AIC:324.12543556003675
#
# ARIMA(0, 0, 1)x(2, 0, 0, 12)- AIC:375.3884033230252
#
# ARIMA(0, 0, 1)x(2, 0, 1, 12)- AIC:373.89336246668967
#
# ARIMA(0, 0, 1)x(2, 0, 2, 12)- AIC:364.72884932355515
#
# ARIMA(0, 0, 1)x(2, 1, 0, 12)- AIC:333.4578899783256
#
# ARIMA(0, 0, 1)x(2, 1, 1, 12)- AIC:335.4119000292891
#
# ARIMA(0, 0, 1)x(2, 1, 2, 12)- AIC:325.1642697365214
#
# ARIMA(0, 0, 2)x(0, 0, 0, 12)- AIC:554.2680894225126
#
# ARIMA(0, 0, 2)x(0, 0, 1, 12)- AIC:466.20139571856583
#
# ARIMA(0, 0, 2)x(0, 0, 2, 12)- AIC:418.7929169593131
#
# ARIMA(0, 0, 2)x(0, 1, 0, 12)- AIC:456.3053245347262
#
# ARIMA(0, 0, 2)x(0, 1, 1, 12)- AIC:359.77428704022304
#
# ARIMA(0, 0, 2)x(0, 1, 2, 12)- AIC:321.6663160745575
#
# ARIMA(0, 0, 2)x(1, 0, 0, 12)- AIC:446.3046878242034
#
# ARIMA(0, 0, 2)x(1, 0, 1, 12)- AIC:415.01948920938304
#
# ARIMA(0, 0, 2)x(1, 0, 2, 12)- AIC:370.5843321700265
#
# ARIMA(0, 0, 2)x(1, 1, 0, 12)- AIC:373.98152055572
#
# ARIMA(0, 0, 2)x(1, 1, 1, 12)- AIC:363.8131481679324
#
# ARIMA(0, 0, 2)x(1, 1, 2, 12)- AIC:322.75741125677905
#
# ARIMA(0, 0, 2)x(2, 0, 0, 12)- AIC:374.2588716744672
#
# ARIMA(0, 0, 2)x(2, 0, 1, 12)- AIC:372.99338937610366
#
# ARIMA(0, 0, 2)x(2, 0, 2, 12)- AIC:362.23599546746243
#
# ARIMA(0, 0, 2)x(2, 1, 0, 12)- AIC:332.2328512564663
#
# ARIMA(0, 0, 2)x(2, 1, 1, 12)- AIC:334.2075364764076
#
# ARIMA(0, 0, 2)x(2, 1, 2, 12)- AIC:323.5520945570223
#
# ARIMA(0, 1, 0)x(0, 0, 0, 12)- AIC:503.1907448387607
#
# ARIMA(0, 1, 0)x(0, 0, 1, 12)- AIC:436.11851130481915
#
# ARIMA(0, 1, 0)x(0, 0, 2, 12)- AIC:402.315385380136
#
# ARIMA(0, 1, 0)x(0, 1, 0, 12)- AIC:500.9761006982901
#
# ARIMA(0, 1, 0)x(0, 1, 1, 12)- AIC:400.4867710716465
#
# ARIMA(0, 1, 0)x(0, 1, 2, 12)- AIC:354.66301938858396
#
# ARIMA(0, 1, 0)x(1, 0, 0, 12)- AIC:441.0287169374492
#
# ARIMA(0, 1, 0)x(1, 0, 1, 12)- AIC:437.57614609990196
#
# ARIMA(0, 1, 0)x(1, 0, 2, 12)- AIC:403.5993130704716
#
# ARIMA(0, 1, 0)x(1, 1, 0, 12)- AIC:416.9307747299227
#
# ARIMA(0, 1, 0)x(1, 1, 1, 12)- AIC:408.8872331917451
#
# ARIMA(0, 1, 0)x(1, 1, 2, 12)- AIC:355.8152406208832
#
# ARIMA(0, 1, 0)x(2, 0, 0, 12)- AIC:400.0722778163681
#
# ARIMA(0, 1, 0)x(2, 0, 1, 12)- AIC:401.4131253529056
#
# ARIMA(0, 1, 0)x(2, 0, 2, 12)- AIC:396.0282929663616
#
# ARIMA(0, 1, 0)x(2, 1, 0, 12)- AIC:359.15729708718186
#
# ARIMA(0, 1, 0)x(2, 1, 1, 12)- AIC:360.8793822705898
#
# ARIMA(0, 1, 0)x(2, 1, 2, 12)- AIC:360.3903134683505
#
# ARIMA(0, 1, 1)x(0, 0, 0, 12)- AIC:485.21431617781104
#
# ARIMA(0, 1, 1)x(0, 0, 1, 12)- AIC:418.45442155331534
#
# ARIMA(0, 1, 1)x(0, 0, 2, 12)- AIC:383.49467156359026
#
# ARIMA(0, 1, 1)x(0, 1, 0, 12)- AIC:468.22293027425223
#
# ARIMA(0, 1, 1)x(0, 1, 1, 12)- AIC:369.9061838298416
#
# ARIMA(0, 1, 1)x(0, 1, 2, 12)- AIC:332.38511770951527
#
# ARIMA(0, 1, 1)x(1, 0, 0, 12)- AIC:422.4118488441566
#
# ARIMA(0, 1, 1)x(1, 0, 1, 12)- AIC:417.28567845172626
#
# ARIMA(0, 1, 1)x(1, 0, 2, 12)- AIC:377.8708626230242
#
# ARIMA(0, 1, 1)x(1, 1, 0, 12)- AIC:384.13655367536836
#
# ARIMA(0, 1, 1)x(1, 1, 1, 12)- AIC:375.2768337263401
#
# ARIMA(0, 1, 1)x(1, 1, 2, 12)- AIC:326.7299434653453
#
# ARIMA(0, 1, 1)x(2, 0, 0, 12)- AIC:376.2347758495557
#
# ARIMA(0, 1, 1)x(2, 0, 1, 12)- AIC:378.065401226774
#
# ARIMA(0, 1, 1)x(2, 0, 2, 12)- AIC:367.00834308779883
#
# ARIMA(0, 1, 1)x(2, 1, 0, 12)- AIC:341.7620199257433
#
# ARIMA(0, 1, 1)x(2, 1, 1, 12)- AIC:343.6877797005483
#
# ARIMA(0, 1, 1)x(2, 1, 2, 12)- AIC:327.9685813113141
#
# ARIMA(0, 1, 2)x(0, 0, 0, 12)- AIC:461.62448527640885
#
# ARIMA(0, 1, 2)x(0, 0, 1, 12)- AIC:405.26552315897266
#
# ARIMA(0, 1, 2)x(0, 0, 2, 12)- AIC:370.9875440766969
#
# ARIMA(0, 1, 2)x(0, 1, 0, 12)- AIC:464.6611249253912
#
# ARIMA(0, 1, 2)x(0, 1, 1, 12)- AIC:364.805508143727
#
# ARIMA(0, 1, 2)x(0, 1, 2, 12)- AIC:324.29559744826895
#
# ARIMA(0, 1, 2)x(1, 0, 0, 12)- AIC:412.09957321095635
#
# ARIMA(0, 1, 2)x(1, 0, 1, 12)- AIC:405.818828071075
#
# ARIMA(0, 1, 2)x(1, 0, 2, 12)- AIC:369.15552546257413
#
# ARIMA(0, 1, 2)x(1, 1, 0, 12)- AIC:378.137630957666
#
# ARIMA(0, 1, 2)x(1, 1, 1, 12)- AIC:367.251452499979
#
# ARIMA(0, 1, 2)x(1, 1, 2, 12)- AIC:322.0599604256373
#
# ARIMA(0, 1, 2)x(2, 0, 0, 12)- AIC:368.0134384423524
#
# ARIMA(0, 1, 2)x(2, 0, 1, 12)- AIC:369.8465638875874
#
# ARIMA(0, 1, 2)x(2, 0, 2, 12)- AIC:358.5463327926932
#
# ARIMA(0, 1, 2)x(2, 1, 0, 12)- AIC:336.4177782628528
#
# ARIMA(0, 1, 2)x(2, 1, 1, 12)- AIC:338.38008886515354
#
# ARIMA(0, 1, 2)x(2, 1, 2, 12)- AIC:323.4390075873887
#
# ARIMA(1, 0, 0)x(0, 0, 0, 12)- AIC:499.8826223391642
#
# ARIMA(1, 0, 0)x(0, 0, 1, 12)- AIC:431.2657201436079
#
# ARIMA(1, 0, 0)x(0, 0, 2, 12)- AIC:396.94389048835393
#
# ARIMA(1, 0, 0)x(0, 1, 0, 12)- AIC:460.01654009528056
#
# ARIMA(1, 0, 0)x(0, 1, 1, 12)- AIC:361.7848406325184
#
# ARIMA(1, 0, 0)x(0, 1, 2, 12)- AIC:323.1853758598971
#
# ARIMA(1, 0, 0)x(1, 0, 0, 12)- AIC:430.89931747033006
#
# ARIMA(1, 0, 0)x(1, 0, 1, 12)- AIC:416.92135195632653
#
# ARIMA(1, 0, 0)x(1, 0, 2, 12)- AIC:372.83544921971315
#
# ARIMA(1, 0, 0)x(1, 1, 0, 12)- AIC:369.7063197298372
#
# ARIMA(1, 0, 0)x(1, 1, 1, 12)- AIC:366.4880420641479
#
# ARIMA(1, 0, 0)x(1, 1, 2, 12)- AIC:324.4728153221865
#
# ARIMA(1, 0, 0)x(2, 0, 0, 12)- AIC:370.1330495651276
#
# ARIMA(1, 0, 0)x(2, 0, 1, 12)- AIC:368.64762223038525
#
# ARIMA(1, 0, 0)x(2, 0, 2, 12)- AIC:364.21312404638
#
# ARIMA(1, 0, 0)x(2, 1, 0, 12)- AIC:327.58448423438114
#
# ARIMA(1, 0, 0)x(2, 1, 1, 12)- AIC:329.55441120739357
#
# ARIMA(1, 0, 0)x(2, 1, 2, 12)- AIC:326.47284560901994
#
# ARIMA(1, 0, 1)x(0, 0, 0, 12)- AIC:488.55738290166295
#
# ARIMA(1, 0, 1)x(0, 0, 1, 12)- AIC:421.1046025888048
#
# ARIMA(1, 0, 1)x(0, 0, 2, 12)- AIC:386.69168266491096
#
# ARIMA(1, 0, 1)x(0, 1, 0, 12)- AIC:458.1904893107478
#
# ARIMA(1, 0, 1)x(0, 1, 1, 12)- AIC:360.9944035728008
#
# ARIMA(1, 0, 1)x(0, 1, 2, 12)- AIC:322.9111782718505
#
# ARIMA(1, 0, 1)x(1, 0, 0, 12)- AIC:421.4112295899769
#
# ARIMA(1, 0, 1)x(1, 0, 1, 12)- AIC:416.0533995752529
#
# ARIMA(1, 0, 1)x(1, 0, 2, 12)- AIC:372.21320686628485
#
# ARIMA(1, 0, 1)x(1, 1, 0, 12)- AIC:371.2949081893292
#
# ARIMA(1, 0, 1)x(1, 1, 1, 12)- AIC:365.79665549522235
#
# ARIMA(1, 0, 1)x(1, 1, 2, 12)- AIC:324.12023400404115
#
# ARIMA(1, 0, 1)x(2, 0, 0, 12)- AIC:371.1782221821149
#
# ARIMA(1, 0, 1)x(2, 0, 1, 12)- AIC:370.1016699557483
#
# ARIMA(1, 0, 1)x(2, 0, 2, 12)- AIC:363.6155206341361
#
# ARIMA(1, 0, 1)x(2, 1, 0, 12)- AIC:329.39040049692306
#
# ARIMA(1, 0, 1)x(2, 1, 1, 12)- AIC:331.3520686491594
#
# ARIMA(1, 0, 1)x(2, 1, 2, 12)- AIC:326.12027112021144
#
# ARIMA(1, 0, 2)x(0, 0, 0, 12)- AIC:466.6946894405264
#
# ARIMA(1, 0, 2)x(0, 0, 1, 12)- AIC:408.02592895372254
#
# ARIMA(1, 0, 2)x(0, 0, 2, 12)- AIC:374.9899014571584
#
# ARIMA(1, 0, 2)x(0, 1, 0, 12)- AIC:457.40969809648277
#
# ARIMA(1, 0, 2)x(0, 1, 1, 12)- AIC:360.4144468122018
#
# ARIMA(1, 0, 2)x(0, 1, 2, 12)- AIC:322.3445915292519
# ARIMA(1, 0, 2)x(1, 0, 0, 12)- AIC:412.0781731460038
#
# ARIMA(1, 0, 2)x(1, 0, 1, 12)- AIC:414.8773779268089
#
# ARIMA(1, 0, 2)x(1, 0, 2, 12)- AIC:371.9157785625397
#
# ARIMA(1, 0, 2)x(1, 1, 0, 12)- AIC:373.2629967585165
#
# ARIMA(1, 0, 2)x(1, 1, 1, 12)- AIC:365.5088890676987
#
# ARIMA(1, 0, 2)x(1, 1, 2, 12)- AIC:323.29138959295517
#
# ARIMA(1, 0, 2)x(2, 0, 0, 12)- AIC:373.05358921603533
#
# ARIMA(1, 0, 2)x(2, 0, 1, 12)- AIC:372.0341076438862
#
# ARIMA(1, 0, 2)x(2, 0, 2, 12)- AIC:362.9128557077886
#
# ARIMA(1, 0, 2)x(2, 1, 0, 12)- AIC:331.1724440399089
#
# ARIMA(1, 0, 2)x(2, 1, 1, 12)- AIC:333.1391150422202
#
# ARIMA(1, 0, 2)x(2, 1, 2, 12)- AIC:325.5195193353603
#
# ARIMA(1, 1, 0)x(0, 0, 0, 12)- AIC:496.09814315718745
#
# ARIMA(1, 1, 0)x(0, 0, 1, 12)- AIC:427.24165602508674
#
# ARIMA(1, 1, 0)x(0, 0, 2, 12)- AIC:393.84015388139557
#
# ARIMA(1, 1, 0)x(0, 1, 0, 12)- AIC:485.28006340999474
#
# ARIMA(1, 1, 0)x(0, 1, 1, 12)- AIC:386.83838702359566
#
# ARIMA(1, 1, 0)x(0, 1, 2, 12)- AIC:344.7538370685058
#
# ARIMA(1, 1, 0)x(1, 0, 0, 12)- AIC:427.6571322555777
#
# ARIMA(1, 1, 0)x(1, 0, 1, 12)- AIC:429.2291030475028
#
# ARIMA(1, 1, 0)x(1, 0, 2, 12)- AIC:390.78831217207187
#
# ARIMA(1, 1, 0)x(1, 1, 0, 12)- AIC:397.98730416564075
#
# ARIMA(1, 1, 0)x(1, 1, 1, 12)- AIC:393.7002087840622
#
# ARIMA(1, 1, 0)x(1, 1, 2, 12)- AIC:346.29728539122823
#
# ARIMA(1, 1, 0)x(2, 0, 0, 12)- AIC:384.9451438980659
#
# ARIMA(1, 1, 0)x(2, 0, 1, 12)- AIC:386.94511477863773
#
# ARIMA(1, 1, 0)x(2, 0, 2, 12)- AIC:384.66639184963446
#
# ARIMA(1, 1, 0)x(2, 1, 0, 12)- AIC:349.43082920242125
#
# ARIMA(1, 1, 0)x(2, 1, 1, 12)- AIC:351.43073281680137
#
# ARIMA(1, 1, 0)x(2, 1, 2, 12)- AIC:352.72268785965065
#
# ARIMA(1, 1, 1)x(0, 0, 0, 12)- AIC:461.9932867626235
#
# ARIMA(1, 1, 1)x(0, 0, 1, 12)- AIC:401.3418961496226
#
# ARIMA(1, 1, 1)x(0, 0, 2, 12)- AIC:369.06556695280887
#
# ARIMA(1, 1, 1)x(0, 1, 0, 12)- AIC:460.15784905646905
#
# ARIMA(1, 1, 1)x(0, 1, 1, 12)- AIC:364.52239971839475
#
# ARIMA(1, 1, 1)x(0, 1, 2, 12)- AIC:324.2809753173344
#
# ARIMA(1, 1, 1)x(1, 0, 0, 12)- AIC:405.3118273320216
#
# ARIMA(1, 1, 1)x(1, 0, 1, 12)- AIC:403.33810512782463
#
# ARIMA(1, 1, 1)x(1, 0, 2, 12)- AIC:368.52938520000896
#
# ARIMA(1, 1, 1)x(1, 1, 0, 12)- AIC:373.59448552366575
#
# ARIMA(1, 1, 1)x(1, 1, 1, 12)- AIC:367.9603541363143
#
# ARIMA(1, 1, 1)x(1, 1, 2, 12)- AIC:324.44771687238733
#
# ARIMA(1, 1, 1)x(2, 0, 0, 12)- AIC:363.4077486350966
#
# ARIMA(1, 1, 1)x(2, 0, 1, 12)- AIC:365.21628415106125
#
# ARIMA(1, 1, 1)x(2, 0, 2, 12)- AIC:359.5597928755321
#
# ARIMA(1, 1, 1)x(2, 1, 0, 12)- AIC:330.81016023446756
#
# ARIMA(1, 1, 1)x(2, 1, 1, 12)- AIC:332.80816005405075
#
# ARIMA(1, 1, 1)x(2, 1, 2, 12)- AIC:325.7422028023943
#
# ARIMA(1, 1, 2)x(0, 0, 0, 12)- AIC:460.7965649017117
#
# ARIMA(1, 1, 2)x(0, 0, 1, 12)- AIC:401.8376277505085
#
# ARIMA(1, 1, 2)x(0, 0, 2, 12)- AIC:368.696310472929
#
# ARIMA(1, 1, 2)x(0, 1, 0, 12)- AIC:458.2966466893921
#
# ARIMA(1, 1, 2)x(0, 1, 1, 12)- AIC:364.004762032635
#
# ARIMA(1, 1, 2)x(0, 1, 2, 12)- AIC:323.34457323121745
#
# ARIMA(1, 1, 2)x(1, 0, 0, 12)- AIC:407.3116043510115
#
# ARIMA(1, 1, 2)x(1, 0, 1, 12)- AIC:403.83093792799946
#
# ARIMA(1, 1, 2)x(1, 0, 2, 12)- AIC:367.89371371828526
#
# ARIMA(1, 1, 2)x(1, 1, 0, 12)- AIC:375.08793447884193
#
# ARIMA(1, 1, 2)x(1, 1, 1, 12)- AIC:367.16393616008384
#
# ARIMA(1, 1, 2)x(1, 1, 2, 12)- AIC:323.8124903185405
#
# ARIMA(1, 1, 2)x(2, 0, 0, 12)- AIC:365.33567644738935
#
# ARIMA(1, 1, 2)x(2, 0, 1, 12)- AIC:367.15364344575676
#
# ARIMA(1, 1, 2)x(2, 0, 2, 12)- AIC:359.38127966216973
#
# ARIMA(1, 1, 2)x(2, 1, 0, 12)- AIC:332.5711374774866
#
# ARIMA(1, 1, 2)x(2, 1, 1, 12)- AIC:334.5687916533289
#
# ARIMA(1, 1, 2)x(2, 1, 2, 12)- AIC:325.2680824840226
#
# ARIMA(2, 0, 0)x(0, 0, 0, 12)- AIC:493.5032279144748
#
# ARIMA(2, 0, 0)x(0, 0, 1, 12)- AIC:426.54270764530304
#
# ARIMA(2, 0, 0)x(0, 0, 2, 12)- AIC:392.59117218920585
#
# ARIMA(2, 0, 0)x(0, 1, 0, 12)- AIC:458.3748254582424
#
# ARIMA(2, 0, 0)x(0, 1, 1, 12)- AIC:363.54394338943416
#
# ARIMA(2, 0, 0)x(0, 1, 2, 12)- AIC:324.88971624540136
#
# ARIMA(2, 0, 0)x(1, 0, 0, 12)- AIC:422.9972769598013
#
# ARIMA(2, 0, 0)x(1, 0, 1, 12)- AIC:416.22608015558626
#
# ARIMA(2, 0, 0)x(1, 0, 2, 12)- AIC:374.24974617948686
#
# ARIMA(2, 0, 0)x(1, 1, 0, 12)- AIC:369.2019919889231
#
# ARIMA(2, 0, 0)x(1, 1, 1, 12)- AIC:365.8526715558855
#
# ARIMA(2, 0, 0)x(1, 1, 2, 12)- AIC:326.3202930210522
#
# ARIMA(2, 0, 0)x(2, 0, 0, 12)- AIC:369.2191770109748
#
# ARIMA(2, 0, 0)x(2, 0, 1, 12)- AIC:368.1084630198336
#
# ARIMA(2, 0, 0)x(2, 0, 2, 12)- AIC:363.77156276494753
#
# ARIMA(2, 0, 0)x(2, 1, 0, 12)- AIC:327.3905835481472
#
# ARIMA(2, 0, 0)x(2, 1, 1, 12)- AIC:329.353814648451
#
# ARIMA(2, 0, 0)x(2, 1, 2, 12)- AIC:326.218457070674
#
# ARIMA(2, 0, 1)x(0, 0, 0, 12)- AIC:466.7293585467653
#
# ARIMA(2, 0, 1)x(0, 0, 1, 12)- AIC:405.6676159391891
#
# ARIMA(2, 0, 1)x(0, 0, 2, 12)- AIC:373.84141646199924
#
# ARIMA(2, 0, 1)x(0, 1, 0, 12)- AIC:459.9601468540027
#
# ARIMA(2, 0, 1)x(0, 1, 1, 12)- AIC:362.58167332157694
#
# ARIMA(2, 0, 1)x(0, 1, 2, 12)- AIC:324.7471345139082
#
# ARIMA(2, 0, 1)x(1, 0, 0, 12)- AIC:405.48709622182025
#
# ARIMA(2, 0, 1)x(1, 0, 1, 12)- AIC:407.323411281121
#
# ARIMA(2, 0, 1)x(1, 0, 2, 12)- AIC:372.56379420293615
#
# ARIMA(2, 0, 1)x(1, 1, 0, 12)- AIC:371.1093813260245
#
# ARIMA(2, 0, 1)x(1, 1, 1, 12)- AIC:367.72219625841507
#
# ARIMA(2, 0, 1)x(1, 1, 2, 12)- AIC:325.8324737763844
#
# ARIMA(2, 0, 1)x(2, 0, 0, 12)- AIC:364.3203535247695
#
# ARIMA(2, 0, 1)x(2, 0, 1, 12)- AIC:366.1042598564179
#
# ARIMA(2, 0, 1)x(2, 0, 2, 12)- AIC:365.4321081182043
#
# ARIMA(2, 0, 1)x(2, 1, 0, 12)- AIC:329.1638988033786
#
# ARIMA(2, 0, 1)x(2, 1, 1, 12)- AIC:331.1442159510882
#
# ARIMA(2, 0, 1)x(2, 1, 2, 12)- AIC:327.9602348191264
#
# ARIMA(2, 0, 2)x(0, 0, 0, 12)- AIC:465.9102504514101
#
# ARIMA(2, 0, 2)x(0, 0, 1, 12)- AIC:405.6754708872684
#
# ARIMA(2, 0, 2)x(0, 0, 2, 12)- AIC:373.76552043006086
#
# ARIMA(2, 0, 2)x(0, 1, 0, 12)- AIC:441.4629965223454
#
# ARIMA(2, 0, 2)x(0, 1, 1, 12)- AIC:361.29817437138564
#
# ARIMA(2, 0, 2)x(0, 1, 2, 12)- AIC:319.92263695787585
#
# ARIMA(2, 0, 2)x(1, 0, 0, 12)- AIC:407.4767979046459
#
# ARIMA(2, 0, 2)x(1, 0, 1, 12)- AIC:407.2751065245635
#
# ARIMA(2, 0, 2)x(1, 0, 2, 12)- AIC:373.91577828501744
#
# ARIMA(2, 0, 2)x(1, 1, 0, 12)- AIC:372.81096221875237
#
# ARIMA(2, 0, 2)x(1, 1, 1, 12)- AIC:367.600878265553
#
# ARIMA(2, 0, 2)x(1, 1, 2, 12)- AIC:322.40036484965503
#
# ARIMA(2, 0, 2)x(2, 0, 0, 12)- AIC:366.2995988365435
#
# ARIMA(2, 0, 2)x(2, 0, 1, 12)- AIC:368.1136208870931
#
# ARIMA(2, 0, 2)x(2, 0, 2, 12)- AIC:364.9074960543596
#
# ARIMA(2, 0, 2)x(2, 1, 0, 12)- AIC:331.25852168802896
#
# ARIMA(2, 0, 2)x(2, 1, 1, 12)- AIC:333.25743798665115
#
# ARIMA(2, 0, 2)x(2, 1, 2, 12)- AIC:327.4913499877081
#
# ARIMA(2, 1, 0)x(0, 0, 0, 12)- AIC:490.9781675248233
#
# ARIMA(2, 1, 0)x(0, 0, 1, 12)- AIC:426.461703547821
#
# ARIMA(2, 1, 0)x(0, 0, 2, 12)- AIC:392.7094903855956
#
# ARIMA(2, 1, 0)x(0, 1, 0, 12)- AIC:478.6582293562409
#
# ARIMA(2, 1, 0)x(0, 1, 1, 12)- AIC:382.69554643293463
#
# ARIMA(2, 1, 0)x(0, 1, 2, 12)- AIC:341.44110393715425
#
# ARIMA(2, 1, 0)x(1, 0, 0, 12)- AIC:423.30991884766286
#
# ARIMA(2, 1, 0)x(1, 0, 1, 12)- AIC:424.54397888064375
#
# ARIMA(2, 1, 0)x(1, 0, 2, 12)- AIC:388.03497141423077
#
# ARIMA(2, 1, 0)x(1, 1, 0, 12)- AIC:391.44164438490867
#
# ARIMA(2, 1, 0)x(1, 1, 1, 12)- AIC:386.8413062961659
#
# ARIMA(2, 1, 0)x(1, 1, 2, 12)- AIC:342.8354801017586
#
# ARIMA(2, 1, 0)x(2, 0, 0, 12)- AIC:379.7608419213979
#
# ARIMA(2, 1, 0)x(2, 0, 1, 12)- AIC:381.7057338628155
#
# ARIMA(2, 1, 0)x(2, 0, 2, 12)- AIC:378.9718024493101
#
# ARIMA(2, 1, 0)x(2, 1, 0, 12)- AIC:343.41546605417807
#
# ARIMA(2, 1, 0)x(2, 1, 1, 12)- AIC:345.41466348278936
#
# ARIMA(2, 1, 0)x(2, 1, 2, 12)- AIC:346.5867091166482
#
# ARIMA(2, 1, 1)x(0, 0, 0, 12)- AIC:464.3200256595825
#
# ARIMA(2, 1, 1)x(0, 0, 1, 12)- AIC:403.33486472072855
#
# ARIMA(2, 1, 1)x(0, 0, 2, 12)- AIC:371.0111650644103
#
# ARIMA(2, 1, 1)x(0, 1, 0, 12)- AIC:461.17809790653723
#
# ARIMA(2, 1, 1)x(0, 1, 1, 12)- AIC:366.3044691023762
#
# ARIMA(2, 1, 1)x(0, 1, 2, 12)- AIC:326.0928749136913
#
# ARIMA(2, 1, 1)x(1, 0, 0, 12)- AIC:403.7164526258895
#
# ARIMA(2, 1, 1)x(1, 0, 1, 12)- AIC:405.33399558698915
#
# ARIMA(2, 1, 1)x(1, 0, 2, 12)- AIC:370.0642333566743
#
# ARIMA(2, 1, 1)x(1, 1, 0, 12)- AIC:372.5550955469622
#
# ARIMA(2, 1, 1)x(1, 1, 1, 12)- AIC:369.6549865547931
#
# ARIMA(2, 1, 1)x(1, 1, 2, 12)- AIC:326.45886183454087
# ARIMA(2, 1, 1)x(2, 0, 0, 12)- AIC:362.4756299247527
#
# ARIMA(2, 1, 1)x(2, 0, 1, 12)- AIC:364.0728445970774
#
# ARIMA(2, 1, 1)x(2, 0, 2, 12)- AIC:361.55968095544864
#
# ARIMA(2, 1, 1)x(2, 1, 0, 12)- AIC:330.13277085875495
#
# ARIMA(2, 1, 1)x(2, 1, 1, 12)- AIC:332.1325006324796
#
# ARIMA(2, 1, 1)x(2, 1, 2, 12)- AIC:327.7445278136081
#
# ARIMA(2, 1, 2)x(0, 0, 0, 12)- AIC:462.86404358731136
#
# ARIMA(2, 1, 2)x(0, 0, 1, 12)- AIC:403.4644718567138
#
# ARIMA(2, 1, 2)x(0, 0, 2, 12)- AIC:370.5452737520523
#
# ARIMA(2, 1, 2)x(0, 1, 0, 12)- AIC:460.1185019938313
#
# ARIMA(2, 1, 2)x(0, 1, 1, 12)- AIC:365.9161914370722
#
# ARIMA(2, 1, 2)x(0, 1, 2, 12)- AIC:325.3386046494805
#
# ARIMA(2, 1, 2)x(1, 0, 0, 12)- AIC:406.11925865658975
#
# ARIMA(2, 1, 2)x(1, 0, 1, 12)- AIC:405.58217178882046
#
# ARIMA(2, 1, 2)x(1, 0, 2, 12)- AIC:369.2435869405988
#
# ARIMA(2, 1, 2)x(1, 1, 0, 12)- AIC:374.53857665989995
#
# ARIMA(2, 1, 2)x(1, 1, 1, 12)- AIC:369.1657606803933
#
# ARIMA(2, 1, 2)x(1, 1, 2, 12)- AIC:323.8790402998794
#
# ARIMA(2, 1, 2)x(2, 0, 0, 12)- AIC:364.3667166776271
#
# ARIMA(2, 1, 2)x(2, 0, 1, 12)- AIC:366.24351200567094
#
# ARIMA(2, 1, 2)x(2, 0, 2, 12)- AIC:361.37142256312563
#
# ARIMA(2, 1, 2)x(2, 1, 0, 12)- AIC:332.0290476895475
#
# ARIMA(2, 1, 2)x(2, 1, 1, 12)- AIC:334.0282813575697
#
# ARIMA(2, 1, 2)x(2, 1, 2, 12)- AIC:327.24065481660705

# %%
df = df.sort_values('AIC').reset_index(drop= True)
df
# Out:
#          param param_seasonal         AIC
# 0    (2, 0, 2)  (0, 1, 2, 12)  319.922637
# 1    (0, 0, 2)  (0, 1, 2, 12)  321.666316
# 2    (0, 1, 2)  (1, 1, 2, 12)  322.059960
# 3    (1, 0, 2)  (0, 1, 2, 12)  322.344592
# 4    (2, 0, 2)  (1, 1, 2, 12)  322.400365
# ..         ...            ...         ...
# 319  (0, 0, 1)  (0, 0, 1, 12)  504.690808
# 320  (0, 0, 2)  (0, 0, 0, 12)  554.268089
# 321  (0, 0, 0)  (0, 0, 1, 12)  580.306267
# 322  (0, 0, 1)  (0, 0, 0, 12)  608.598526
# 323  (0, 0, 0)  (0, 0, 0, 12)  712.659077
#
# [324 rows x 3 columns]

# %% [markdown]
# The above output suggests that SARIMAX(3,0,0)(3,0,0,12) yields the lowest AIC value of 328.424883. Therefore we should consider this to be the optimal option.

# %%
mod = sm.tsa.statespace.SARIMAX(train['Sum of Sales'],
                                order=(2, 0, 2),
                                seasonal_order=(0, 1, 2, 12))
results = mod.fit()
print(results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                       Sum of Sales   No. Observations:                  143
# Model:             SARIMAX(2, 0, 2)x(0, 1, 2, 12)   Log Likelihood                -205.284
# Date:                            Mon, 29 Mar 2021   AIC                            424.569
# Time:                                    16:27:49   BIC                            444.695
# Sample:                                         0   HQIC                           432.747
#                                             - 143
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2474      0.573     -0.432      0.666      -1.371       0.876
# ar.L2          0.4983      0.220      2.262      0.024       0.067       0.930
# ma.L1          0.5970      0.592      1.009      0.313      -0.562       1.756
# ma.L2         -0.2711      0.321     -0.845      0.398      -0.900       0.358
# ma.S.L12      -0.6864      0.082     -8.373      0.000      -0.847      -0.526
# ma.S.L24       0.0932      0.104      0.897      0.370      -0.110       0.297
# sigma2         1.2781      0.115     11.162      0.000       1.054       1.503
# ===================================================================================
# Ljung-Box (Q):                       31.37   Jarque-Bera (JB):               102.89
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                             0.94
# Prob(H) (two-sided):                  0.53   Kurtosis:                         6.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0833238df0b5> in <module>
# ----> 1 print(solve_discrete_lyapunov([[1 - 6e-17]], [[1.]]))
#
# NameError: name 'solve_discrete_lyapunov' is not defined

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# Here we will forecast the values using the model. Can change starting point from which we need to forecast. For now we will keep starting point after 50 observations

# %%
#Point from which prediction starts
start_point = 50
pred = results.get_prediction(start=start_point)
pred_ci = pred.conf_int()
ax = sales['Sum of Sales'].plot(label='observed',)
pred.predicted_mean.plot(ax=ax, label='Forecasting', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
plt.legend()
plt.show()

# %%
results.forecast(steps=12)
# Out:
# 143    4.136630
# 144    4.384034
# 145    3.066034
# 146    2.910378
# 147    2.639025
# 148    2.659244
# 149    3.187983
# 150    2.360921
# 151    1.967841
# 152    1.917107
# 153    4.864995
# 154    5.294410
# dtype: float64

# %%
pred_uc = results.get_forecast(steps=12)
pred_ci = pred_uc.conf_int()
ax = sales.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# # Model Evaluation
#  - Mean Absolute Percentage Error
#  - Mean Absolute Error
#  - BIAS
#  - Mean Squared Error
#  - Root Mean Squared Error

# %%
predictions = pred.predicted_mean
actual = train['Sum of Sales'][start_point:]

# %%
me.evaluate_model(predictions,actual)
# Out:
# ===================================================================
# 			Model Performance
# ===================================================================
#
# Mean Absolute Percentage Error: 0.2826080329042971
#
# Mean Absolute Error: 0.7120929374593618
#
# BIAS: 0.11506299517800084
#
# Mean Squared Error: 1.231272835917936
#
# Root Mean Squared Error: 1.1096273410104565
# ===================================================================

# %%
test_prediction = results.forecast(steps=12)
test_prediction
# Out:
# 143    4.268835
# 144    4.798267
# 145    2.996645
# 146    2.948519
# 147    2.479544
# 148    2.236837
# 149    2.318097
# 150    1.605763
# 151    1.519410
# 152    1.438802
# 153    4.764220
# 154    4.344412
# dtype: float64

# %%
test_actual = test['Sum of Sales']
test_actual
# Out:
# 143     5.255255
# 144     5.733124
# 145     2.894873
# 146     2.462465
# 147     2.193816
# 148     1.286718
# 149     1.367123
# 150     1.503481
# 151     1.560669
# 152     4.687110
# 153    11.184468
# 154     4.291668
# Name: Sum of Sales, dtype: float64

# %%
me.evaluate_model(test_prediction,test_actual)
# Out:
# ===================================================================
# 			Model Performance
# ===================================================================
#
# Mean Absolute Percentage Error: 0.2934478398799947
#
# Mean Absolute Error: 1.2133970120593929
#
# BIAS: 0.7251182482827895
#
# Mean Squared Error: 6.309557687912413
#
# Root Mean Squared Error: 2.5118832950422703
# ===================================================================
