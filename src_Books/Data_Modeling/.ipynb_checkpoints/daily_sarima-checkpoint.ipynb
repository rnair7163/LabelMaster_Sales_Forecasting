# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
import pandas as pd
import statsmodels.api as sm
import matplotlib

from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
 
from itertools import product
from tqdm import tqdm_notebook

import Model_Evaluation as me

# %%
#books = pd.read_csv('/Users/rahulnair/Desktop/Labelmaster_/src/Data_Prep/sales_from_2008.csv')
#books = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LabelMaster/LabelMaster Data/Books_ext.csv')
books = pd.read_csv('/Users/rahulnair/Desktop/Labelmaster_/src/Data_Prep/sales_from_2008.csv')
#books = pd.read_csv('C:/Users/11602/OneDrive/Practicum/LabelMaster_Sales_Forecasting/data/Books_ext_fs.csv')
# books = pd.read_csv('C:/Users/Sword Guo/OneDrive/Practicum/LabelMaster_Sales_Forecasting/data/Books_ext_fs.csv')
# sales = books[['Year_Month','Sum of Sales']]
sales = books.drop(['Unnamed: 0'], axis=1)
sales['Sum of Sales'] = sales['Sum of Sales']/100000
sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e49c47489f36> in <module>
#       4 # books = pd.read_csv('C:/Users/Sword Guo/OneDrive/Practicum/LabelMaster_Sales_Forecasting/data/Books_ext_fs.csv')
#       5 # sales = books[['Year_Month','Sum of Sales']]
# ----> 6 sales = books.drop(['Unnamed: 0'], axis=1)
#       7 sales['Sum of Sales'] = sales['Sum of Sales']/100000
#       8 sales
#
# NameError: name 'books' is not defined

# %%
train, test = train_test_split(sales, test_size=0.075, random_state=60616, shuffle=False)

# %%
p = [0,1,2]
d = [0,1]
q = [0,1,2]
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 30) for x in list(itertools.product(p, d, q))]

df = pd.DataFrame()
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train['Sum of Sales'],
                                            order=param,
                                            seasonal_order=param_seasonal)
            results = mod.fit()
            print('ARIMA{}x{}- AIC:{}'.format(param, param_seasonal, results.aic))

            combo = [(param,param_seasonal,results.aic)]
            df = df.append(combo)
            print(" ")
        except:
            continue
df.columns = ['param','param_seasonal', 'AIC']
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 30)- AIC:-725.8538673520831
#
# ARIMA(0, 0, 0)x(0, 0, 1, 30)- AIC:-1538.171689333287
#
# ARIMA(0, 0, 0)x(0, 0, 2, 30)- AIC:-1955.7545942958059
#
# ARIMA(0, 0, 0)x(0, 1, 0, 30)- AIC:170.97353163418381
#
# ARIMA(0, 0, 0)x(0, 1, 1, 30)- AIC:-3903.130599392139
#
# ARIMA(0, 0, 0)x(0, 1, 2, 30)- AIC:-3905.568048664973
#
# ARIMA(0, 0, 0)x(1, 0, 0, 30)- AIC:-2011.4797259833572
#
# ARIMA(0, 0, 0)x(1, 0, 1, 30)- AIC:-3933.4505587750427

# %%
df = df.sort_values('AIC').reset_index(drop= True)
df

# %%
mod = sm.tsa.statespace.SARIMAX(train['Sum of Sales'],
                                order=(2, 0, 1),
                                seasonal_order=(2, 0, 2, 12))
results = mod.fit()
print(results.summary())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                       Sum of Sales   No. Observations:                 6468
# Model:             SARIMAX(2, 0, 1)x(2, 0, 2, 12)   Log Likelihood                2636.046
# Date:                            Thu, 01 Apr 2021   AIC                          -5256.092
# Time:                                    17:59:04   BIC                          -5201.895
# Sample:                                         0   HQIC                         -5237.342
#                                            - 6468
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1564      0.013     88.430      0.000       1.131       1.182
# ar.L2         -0.1978      0.008    -23.877      0.000      -0.214      -0.182
# ma.L1         -0.8542      0.012    -71.720      0.000      -0.878      -0.831
# ar.S.L12       0.0403      0.045      0.893      0.372      -0.048       0.129
# ar.S.L24       0.9588      0.045     21.538      0.000       0.872       1.046
# ma.S.L12      -0.0312      0.044     -0.703      0.482      -0.118       0.056
# ma.S.L24      -0.9539      0.044    -21.845      0.000      -1.039      -0.868
# sigma2         0.0258   8.61e-05    300.077      0.000       0.026       0.026
# ===================================================================================
# Ljung-Box (Q):                       93.80   Jarque-Bera (JB):           2584483.36
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.73   Skew:                             6.81
# Prob(H) (two-sided):                  0.00   Kurtosis:                        99.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
#Point from which prediction starts
start_point = 50
pred = results.get_prediction(start=start_point)
pred_ci = pred.conf_int()
ax = sales['Sum of Sales'].plot(label='observed',)
pred.predicted_mean.plot(ax=ax, label='Predicted', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
plt.legend()
plt.show()

# %%
pred_uc = results.get_forecast(steps=12)
pred_ci = pred_uc.conf_int()
ax = sales.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
predictions = pred.predicted_mean
actual = train['Sum of Sales'][start_point:]
me.evaluate_model(predictions,actual)
# Out:
# ===================================================================
# 			Model Performance
# ===================================================================
#
# Mean Absolute Percentage Error: inf
#
# Mean Absolute Error: 0.08059356474245594
#
# BIAS: 0.0036012797606621533
#
# Mean Squared Error: 0.08323642773961308
#
# Root Mean Squared Error: 0.28850724035908193
# ===================================================================

# %%
test_prediction = results.forecast(steps=12)
test_actual = test['Sum of Sales']
me.evaluate_model(test_prediction,test_actual)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d6dfe62c1166> in <module>
#       1 test_prediction = results.forecast(steps=12)
#       2 test_actual = test['Sum of Sales']
# ----> 3 me.evaluate_model(test_prediction,test_actual)
#
# ~/Desktop/Labelmaster_/src/Data_Modeling/Model_Evaluation.py in evaluate_model(predictions, actual)
#      29 def evaluate_model(predictions,actual):
#      30
# ---> 31         BIAS = find_bias(predictions,actual)
#      32         MAE = mean_absolute_error(predictions,actual)
#      33         MAPE = mean_absolute_percent_error(predictions,actual)
#
# ~/Desktop/Labelmaster_/src/Data_Modeling/Model_Evaluation.py in find_bias(predictions, actual)
#       6 # Bias of the model
#       7 def find_bias(predictions,actual):
# ----> 8         error = np.array(actual) - np.array(predictions)
#       9         bias = sum(error)/len(error)
#      10         return  bias
#
# ValueError: operands could not be broadcast together with shapes (525,) (12,)
